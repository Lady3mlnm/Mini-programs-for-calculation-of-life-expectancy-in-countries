# %% [markdown]
# "[Список стран по ожидаемой продолжительности жизни](https://ru.wikipedia.org/wiki/Список_стран_по_ожидаемой_продолжительности_жизни)"<br />
# "[Продолжительность жизни в субъектах Российской Федерации](https://ru.wikipedia.org/wiki/Продолжительность_жизни_в_субъектах_Российской_Федерации)"<br />
# [fedstat.ru](https://www.fedstat.ru/indicator/31293) (ЕМИСС - Единая межведомственная информационно-статистическая система)

# %%
import pandas as pd
import numpy as np
import math

# %%
pd.options.display.max_rows = 200
pd.options.display.max_columns = 50

# %%
# load stats about longevity per year
df = pd.read_excel('data/Rosstat_by_year_and_region.xls', skiprows=2)

print(df.shape)
df.head(2)
# Out:
# (108, 34)
#                           Unnamed: 0 Unnamed: 1     Unnamed: 2  1990  1991  \
# 0               Российская Федерация   Оба пола  все население  69.2  68.9
# 1      Центральный федеральный округ   Оба пола  все население  69.5  69.2
#
#    1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  \
# 0  67.8  65.0  63.9  64.5  65.8  66.7  67.1  65.9  65.3  65.2  65.0  64.9
# 1  68.3  65.6  64.2  64.9  66.5  67.4  67.6  66.4  66.1  65.8  65.6  65.7
#
#    2004  2005  2006  2007  2008  2009  2010   2011   2012   2013   2014  \
# 0  65.3  65.4  66.7  67.6  68.0  68.8  68.9  69.83  70.24  70.76  70.93
# 1  66.3  66.5  67.6  68.4  68.8  69.7  69.9  71.19  71.43  71.93  72.10
#
#     2015   2016   2017   2018   2019   2020
# 0  71.39  71.87  72.70  72.91  73.34  71.54
# 1  72.72  73.07  73.89  74.01  74.54  72.57

# %%
# remove surrounding spaces in the column with names of regions
df['Unnamed: 0'] = df['Unnamed: 0'].map(lambda st: st.strip())

# convert region column to index
df.set_index('Unnamed: 0', inplace=True)

# for brevityh of display remove name of index column.
df.index.name = ''

# sort index to speed up further transformations
df.sort_index(inplace=True)

# patch for Ingushetia for 1990-1992
# df.loc['Республика Ингушетия', '1990':'1992'] = df.loc['Чеченская и Ингушская Республики', '1990':'1992']

print(df.shape)
df.head(2)
# Out:
# (108, 33)
#                                               Unnamed: 1     Unnamed: 2  1990  \
#
# Агинский Бурятский округ (Забайкальский край)   Оба пола  все население   NaN
# Алтайский край                                  Оба пола  все население  68.9
#
#                                                1991  1992  1993  1994  1995  \
#
# Агинский Бурятский округ (Забайкальский край)   NaN   NaN  62.4  59.9  62.7
# Алтайский край                                 68.4  67.7  65.0  64.0  64.3
#
#                                                1996  1997  1998  1999  2000  \
#
# Агинский Бурятский округ (Забайкальский край)  62.3  63.9  63.5  62.8  61.9
# Алтайский край                                 65.3  66.0  67.8  66.8  66.6
#
#                                                2001  2002  2003  2004  2005  \
#
# Агинский Бурятский округ (Забайкальский край)  61.3  62.2   NaN   NaN   NaN
# Алтайский край                                 66.3  65.6  65.7  65.5  64.6
#
#                                                2006  2007  2008  2009  2010  \
#
# Агинский Бурятский округ (Забайкальский край)   NaN   NaN   NaN   NaN   NaN
# Алтайский край                                 66.5  67.1  67.4  68.4  68.4
#
#                                                 2011   2012   2013   2014  \
#
# Агинский Бурятский округ (Забайкальский край)    NaN    NaN    NaN    NaN
# Алтайский край                                 68.97  69.11  69.77  70.01
#
#                                                 2015   2016  2017   2018  \
#
# Агинский Бурятский округ (Забайкальский край)    NaN    NaN   NaN    NaN
# Алтайский край                                 70.44  70.74  71.1  71.11
#
#                                                 2019   2020
#
# Агинский Бурятский округ (Забайкальский край)    NaN    NaN
# Алтайский край                                 71.61  70.19

# %%
def filter_regions(df_regions: 'dataframe', errors='raise'):
    """
    The function takes dataframe with regions, remove some rows and rename others.
    """
    
    ls_dropping = [
        'Центральный федеральный округ',
        'Северо-Западный федеральный округ',
        'Южный федеральный округ (по 2009 год)',
        'Южный федеральный округ (с 2010 года)',
        'Южный федеральный округ (с 29.07.2016)',
        'Северо-Кавказский федеральный округ',
        'Приволжский федеральный округ',
        'Уральский федеральный округ',
        'Сибирский федеральный округ',
        'Дальневосточный федеральный округ',
        'Крымский федеральный округ',
        'Коми-Пермяцкий округ, входящий в состав Пермского края',
        'Таймырский (Долгано-Ненецкий) автономный округ (Красноярский край)',
        'Эвенкийский автономный округ (Красноярский край)',
        'Усть-Ордынский Бурятский округ',
        'Агинский Бурятский округ (Забайкальский край)',
        'Корякский округ, входящий в состав Камчатского края',
        'Чеченская и Ингушская Республики' 
    ]

    dict_renaming = {
        'Российская Федерация': 'Россия в среднем',
        'Город Москва столица Российской Федерации город федерального значения': 'г. Москва',
        'Город Санкт-Петербург город федерального значения': 'г. Санкт-Петербург',
        'Республика Адыгея (Адыгея)': 'Республика Адыгея',
        'Город федерального значения Севастополь': 'г. Севастополь',
        'Республика Татарстан (Татарстан)': 'Республика Татарстан',
        'Чувашская Республика - Чувашия': 'Чувашская Республика (Чувашия)'
    }
    
    return df_regions.drop(ls_dropping, errors=errors) \
                     .rename(index=dict_renaming, errors=errors) \
                     .sort_index()
    
df = filter_regions(df)
print(df.shape)
df.head(2)
# Out:
# (88, 33)
#                  Unnamed: 1     Unnamed: 2  1990  1991  1992  1993  1994  \
#
# Алтайский край     Оба пола  все население  68.9  68.4  67.7  65.0  64.0
# Амурская область   Оба пола  все население  67.8  67.4  65.8  62.8  62.1
#
#                   1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  \
#
# Алтайский край    64.3  65.3  66.0  67.8  66.8  66.6  66.3  65.6  65.7  65.5
# Амурская область  63.0  62.9  63.6  64.5  63.1  62.2  61.3  61.1  60.9  60.3
#
#                   2005  2006  2007  2008  2009  2010   2011   2012   2013  \
#
# Алтайский край    64.6  66.5  67.1  67.4  68.4  68.4  68.97  69.11  69.77
# Амурская область  60.2  62.1  63.8  63.4  64.2  64.4  64.82  65.12  66.38
#
#                    2014   2015   2016   2017   2018   2019   2020
#
# Алтайский край    70.01  70.44  70.74  71.10  71.11  71.61  70.19
# Амурская область  67.00  67.27  68.28  69.06  69.11  68.66  67.38

# %%
# select only required columns
df = df[['1991', '2000', '2014', '2019', '2020']]  # df[['2020', '2019', '2014', '2000', '1991', '1990']]

print(df.shape)
df.head(2)
# Out:
# (88, 5)
#                   1991  2000   2014   2019   2020
#
# Алтайский край    68.4  66.6  70.01  71.61  70.19
# Амурская область  67.4  62.2  67.00  68.66  67.38

# %% [markdown]
# <br />
# <br />
# <br />

# %%
# load stats about longevity per gender ('genloc' is abbreviation for 'gender and location'
genloc = pd.read_excel('data/Rosstat_by_gender_and_location_2020.xls', skiprows=2)

print(genloc.shape)
genloc.head(10)
# Out:
# (864, 4)
#                           Unnamed: 0 Unnamed: 1           Unnamed: 2   2020
# 0               Российская Федерация    Женщины        все население  76.43
# 1               Российская Федерация    Женщины  городское население  76.61
# 2               Российская Федерация    Женщины   сельское население  75.82
# 3               Российская Федерация    Мужчины        все население  66.49
# 4               Российская Федерация    Мужчины  городское население  66.67
# 5               Российская Федерация    Мужчины   сельское население  65.97
# 6               Российская Федерация   Оба пола        все население  71.54
# 7               Российская Федерация   Оба пола  городское население  71.81
# 8               Российская Федерация   Оба пола   сельское население  70.69
# 9      Центральный федеральный округ    Женщины        все население  77.24

# %%
# rename columns
genloc.rename(columns={'Unnamed: 0': 'region', 'Unnamed: 1': 'gender', 'Unnamed: 2': 'location'}, inplace=True)

# remove surrounding spaces in the column with names of regions
genloc['region'] = genloc['region'].map(lambda st: st.strip())

genloc.head(10)
# Out:
#                           region    gender             location   2020
# 0           Российская Федерация   Женщины        все население  76.43
# 1           Российская Федерация   Женщины  городское население  76.61
# 2           Российская Федерация   Женщины   сельское население  75.82
# 3           Российская Федерация   Мужчины        все население  66.49
# 4           Российская Федерация   Мужчины  городское население  66.67
# 5           Российская Федерация   Мужчины   сельское население  65.97
# 6           Российская Федерация  Оба пола        все население  71.54
# 7           Российская Федерация  Оба пола  городское население  71.81
# 8           Российская Федерация  Оба пола   сельское население  70.69
# 9  Центральный федеральный округ   Женщины        все население  77.24

# %%
# make dataframe multi-index
genloc = genloc.sort_values(by=['region', 'gender', 'location']) \
               .set_index(['region', 'gender', 'location'])

print(genloc.shape)
genloc.head(10)
# Out:
# (864, 1)
#                                                 2020
# region           gender   location
# Алтайский край   Женщины  все население        75.16
#                           городское население  75.29
#                           сельское население   74.70
#                  Мужчины  все население        65.18
#                           городское население  65.13
#                           сельское население   64.88
#                  Оба пола все население        70.19
#                           городское население  70.36
#                           сельское население   69.64
# Амурская область Женщины  все население        72.79

# %%
# filter records: remove some ot them and rename others
genloc = filter_regions(genloc, errors='ignore')

print(genloc.shape)
genloc.head(10)
# Out:
# (792, 1)
#                                                 2020
# region           gender   location
# Алтайский край   Женщины  все население        75.16
#                           городское население  75.29
#                           сельское население   74.70
#                  Мужчины  все население        65.18
#                           городское население  65.13
#                           сельское население   64.88
#                  Оба пола все население        70.19
#                           городское население  70.36
#                           сельское население   69.64
# Амурская область Женщины  все население        72.79

# %%
# reshape dataframe, transforming the last two levels of multi-index to columns
genloc = genloc.unstack().unstack()
genloc.head(2)
# Out:
#                           2020                                               \
# location         все население                  городское население
# gender                 Женщины Мужчины Оба пола             Женщины Мужчины
# region
# Алтайский край           75.16   65.18    70.19               75.29   65.13
# Амурская область         72.79   62.27    67.38               73.10   62.53
#
#
# location                  сельское население
# gender           Оба пола            Женщины Мужчины Оба пола
# region
# Алтайский край      70.36              74.70   64.88    69.64
# Амурская область    67.83              71.89   61.68    66.36

# %%
# simplify heading
heading = genloc.columns
genloc.columns = map(lambda tp: '-'.join(tp[1:]), heading)

genloc.head(2)
# Out:
#                   все население-Женщины  все население-Мужчины  \
# region
# Алтайский край                    75.16                  65.18
# Амурская область                  72.79                  62.27
#
#                   все население-Оба пола  городское население-Женщины  \
# region
# Алтайский край                     70.19                        75.29
# Амурская область                   67.38                        73.10
#
#                   городское население-Мужчины  городское население-Оба пола  \
# region
# Алтайский край                          65.13                         70.36
# Амурская область                        62.53                         67.83
#
#                   сельское население-Женщины  сельское население-Мужчины  \
# region
# Алтайский край                         74.70                       64.88
# Амурская область                       71.89                       61.68
#
#                   сельское население-Оба пола
# region
# Алтайский край                          69.64
# Амурская область                        66.36

# %%
# choose only required to us columns and place them in required order
genloc = genloc[[
    'все население-Оба пола',
    'все население-Мужчины',
    'все население-Женщины',
    'городское население-Оба пола',
    'сельское население-Оба пола'    
]].rename(columns={
    'все население-Оба пола': 'overall',
    'все население-Мужчины': 'males',
    'все население-Женщины': 'females',
    'городское население-Оба пола': 'urban',
    'сельское население-Оба пола': 'rural'
})


# if in some column there's 0, than change it to NaN (it's actual for Saint Petersburg)
genloc.replace(0, np.nan, inplace=True)

genloc.head(2)
# Out:
#                   overall  males  females  urban  rural
# region
# Алтайский край      70.19  65.18    75.16  70.36  69.64
# Амурская область    67.38  62.27    72.79  67.83  66.36

# %% [markdown]
# <br />

# %%
# before joining two dataframes make sure correctness of transformations
assert len(df) == len(genloc), "Problem wiht length of dataframes"
assert all(df.index == genloc.index), "Problem with indexes of dataframes"
assert all(df['2020'] == genloc['overall']), "content of the column '2020' is not identical to columns 'all_population'"

# %%
# concatinate info from two database
df = pd.concat([genloc, df], axis='columns')
df.head(2)
# Out:
#                   overall  males  females  urban  rural  1991  2000   2014  \
# Алтайский край      70.19  65.18    75.16  70.36  69.64  68.4  66.6  70.01
# Амурская область    67.38  62.27    72.79  67.83  66.36  67.4  62.2  67.00
#
#                    2019   2020
# Алтайский край    71.61  70.19
# Амурская область  68.66  67.38

# %%
# calculate difference between some columns and insert result as new columns in dataframe
df.insert(loc=3, column='females_vs_males', value=df['females']-df['males'])
df.insert(loc=6, column='urban_vs_rural', value=df['urban']-df['rural'])
df.insert(loc=8, column='1991→2000', value=df['2000']-df['1991'])
df.insert(loc=10, column='2000→2014', value=df['2014']-df['2000'])
df.insert(loc=12, column='2014→2019', value=df['2019']-df['2014'])
df.insert(loc=14, column='2019→2020', value=df['2020']-df['2019'])
df.head(2)
# Out:
#                   overall  males  females  females_vs_males  urban  rural  \
# Алтайский край      70.19  65.18    75.16              9.98  70.36  69.64
# Амурская область    67.38  62.27    72.79             10.52  67.83  66.36
#
#                   urban_vs_rural  1991  1991→2000  2000  2000→2014   2014  \
# Алтайский край              0.72  68.4       -1.8  66.6       3.41  70.01
# Амурская область            1.47  67.4       -5.2  62.2       4.80  67.00
#
#                   2014→2019   2019  2019→2020   2020
# Алтайский край         1.60  71.61      -1.42  70.19
# Амурская область       1.66  68.66      -1.28  67.38

# %%
# sort table by 'all_population'
df.sort_values(by=['overall', '2019'], ascending=False, inplace=True)

# %%
# move some records to the top of dataframe (by default, column 'Россия в среднем')
# change order of some regions
indexes = df.index.to_list()
ls_change_order = ['Россия в среднем']    # 'г. Москва', 'г. Санкт-Петербург', 'г. Севастополь'
indexes = list(el for el in indexes if el not in ls_change_order)
indexes = ls_change_order + indexes
df = df.reindex(indexes)

# %%
ls_dropping = [
    'Архангельская область',
    'Тюменская область'
]

# %%
df_subjects = df.drop(index=ls_dropping)
print(df_subjects.shape)
df_subjects.fillna(' ')
# Out:
# (86, 16)
#                                                     overall  males  females  \
# Россия в среднем                                      71.54  66.49    76.43
# Республика Ингушетия                                  81.48  77.43    84.61
# Республика Дагестан                                   76.43  73.33    79.39
# г. Москва                                             76.20  72.39    79.77
# Карачаево-Черкесская Республика                       74.82  70.51    78.83
# Кабардино-Балкарская Республика                       74.37  70.16    78.27
# Республика Северная Осетия-Алания                     74.08  68.84    78.96
# г. Санкт-Петербург                                    73.99  69.30    78.10
# г. Севастополь                                        73.58  68.70    78.27
# Республика Адыгея                                     73.27  68.70    77.58
# Ставропольский край                                   73.20  68.51    77.68
# Республика Калмыкия                                   72.93  67.92    77.90
# Калининградская область                               72.93  68.39    77.05
# Ханты-Мансийский автономный округ - Югра (Тюмен...    72.87  68.76    76.91
# Республика Татарстан                                  72.61  67.35    77.72
# Белгородская область                                  72.37  67.49    77.12
# Краснодарский край                                    72.24  67.33    77.05
# Чеченская Республика                                  72.11  69.49    74.65
# Ростовская область                                    72.04  67.41    76.50
# Астраханская область                                  72.01  67.51    76.35
# Волгоградская область                                 71.98  67.10    76.75
# Ямало-Ненецкий автономный округ (Тюменская обла...    71.91  67.54    76.21
# Воронежская область                                   71.91  66.41    77.37
# Тамбовская область                                    71.78  66.60    76.95
# Московская область                                    71.67  66.74    76.36
# Республика Мордовия                                   71.60  66.80    76.41
# Ленинградская область                                 71.53  66.32    76.75
# Кировская область                                     71.42  65.99    76.86
# Архангельская область (кроме Ненецкого автономн...    71.39  65.79    77.01
# Пензенская область                                    71.34  66.10    76.49
# Тюменская область (кроме Ханты-Мансийского авто...    71.34  66.17    76.51
# Республика Крым                                       71.20  66.22    76.04
# Томская область                                       71.17  65.96    76.38
# Саратовская область                                   71.14  66.31    75.75
# Республика Саха (Якутия)                              71.10  66.06    76.29
# Республика Марий Эл                                   71.05  65.24    77.02
# Чувашская Республика (Чувашия)                        71.03  65.46    76.84
# Удмуртская Республика                                 71.03  65.30    76.66
# Ульяновская область                                   70.98  65.91    75.94
# Рязанская область                                     70.95  65.74    76.05
# Ярославская область                                   70.94  65.40    76.19
# Костромская область                                   70.92  65.73    75.98
# Вологодская область                                   70.71  64.89    76.57
# Краснодарский край                                  72.74          -0.88
# Чеченская Республика                                 77.5         -11.02
# Ростовская область                                  71.39           0.94
# Астраханская область                                71.53           0.64
# Волгоградская область                               70.71           1.64
# Ямало-Ненецкий автономный округ (Тюменская обла...  68.73           3.86
# Воронежская область                                 71.56           0.48
# Тамбовская область                                  71.47           0.43
# Московская область                                   73.3          -1.96
# Республика Мордовия                                 70.34            1.8
# Ленинградская область                                73.1          -2.25
# Кировская область                                   68.58           3.43
# Архангельская область (кроме Ненецкого автономн...  68.05           4.06
# Пензенская область                                  70.51           1.18
# Тюменская область (кроме Ханты-Мансийского авто...  69.16           3.22
# Республика Крым                                      71.7          -0.98
# Томская область                                     69.67            2.0
# Саратовская область                                 70.46           0.88
# Республика Саха (Якутия)                            69.76           1.91
# Республика Марий Эл                                 69.05           2.96
# Чувашская Республика (Чувашия)                      69.17           2.78
# Удмуртская Республика                               69.83           1.71
# Ульяновская область                                 69.98           1.21
# Рязанская область                                   71.06          -0.25
# Ярославская область                                  71.1          -0.22
# Костромская область                                 69.99           1.14
# Вологодская область                                 69.05           2.14
# Ивановская область                                  70.37            0.3
# Брянская область                                    70.03           0.85
# Липецкая область                                    70.04           0.78
# Курская область                                      69.6           1.25
# Самарская область                                   70.17           0.35
# Ненецкий автономный округ (Архангельская область)   63.73           8.78
# Калужская область                                   71.03          -0.84
# Республика Башкортостан                             69.18           1.78
# Нижегородская область                               70.13           0.22
# Омская область                                      68.96           1.83
# Новосибирская область                                68.3           2.51
# Республика Коми                                     66.67           4.39
# Челябинская область                                 68.65           1.96
# Республика Бурятия                                  68.65            2.7
# Тульская область                                    71.05          -1.08
# Алтайский край                                      69.64           0.72
# Свердловская область                                 68.7           1.68
# Орловская область                                   69.55           0.76
# Смоленская область                                  68.72           1.88
# Республика Хакасия                                  67.85           3.19
# Владимирская область                                70.87          -1.08
# Курганская область                                  69.27           0.95
# Красноярский край                                    67.6           2.79
# Мурманская область                                  73.02          -3.43
# Тверская область                                    69.27            0.6
# Оренбургская область                                69.15           0.74
# Сахалинская область                                 67.75           2.37
# Республика Карелия                                  65.01            5.6
# Пермский край                                        68.3           1.68
# Новгородская область                                69.24           0.34
# Приморский край                                     67.53           2.59
# Камчатский край                                     65.49           4.76
# Республика Алтай                                    68.31           1.77
# Псковская область                                   68.76            0.3
# Магаданская область                                  60.6           8.74
# Хабаровский край                                    67.38            1.5
# Кемеровская область - Кузбасс                       67.95           0.64
# Иркутская область                                    66.9           1.73
# Забайкальский край                                  66.47           2.44
# Еврейская автономная область                        67.45           0.17
# Амурская область                                    66.36           1.47
# Республика Тыва                                     62.49           6.06
# Чукотский автономный округ                          56.97          12.32
#
#                                                     1991 1991→2000  2000  \
# Россия в среднем                                    68.9      -3.6  65.3
# Республика Ингушетия                                                72.0
# Республика Дагестан                                 72.6      -1.6  71.0
# г. Москва                                           69.8       0.0  69.8
# Карачаево-Черкесская Республика                     71.9      -3.5  68.4
# Кабардино-Балкарская Республика                     70.5      -1.4  69.1
# Республика Северная Осетия-Алания                   70.5      -2.1  68.4
# г. Санкт-Петербург                                  69.5      -2.8  66.7
# г. Севастополь
# Республика Адыгея                                   68.3      -0.7  67.6
# Ставропольский край                                 69.3      -1.3  68.0
# Республика Калмыкия                                 68.0      -2.6  65.4
# Калининградская область                             68.5      -4.9  63.6
# Ханты-Мансийский автономный округ - Югра (Тюмен...                  65.9
# Республика Татарстан                                70.6      -3.0  67.6
# Белгородская область                                69.8      -1.7  68.1
# Краснодарский край                                  68.3      -1.2  67.1
# Чеченская Республика                                69.8
# Ростовская область                                  69.0      -2.5  66.5
# Астраханская область                                69.1      -3.8  65.3
# Волгоградская область                               70.4      -4.0  66.4
# Ямало-Ненецкий автономный округ (Тюменская обла...                  66.7
# Воронежская область                                 69.7      -3.2  66.5
# Тамбовская область                                  68.2      -3.2  65.0
# Московская область                                  69.4      -4.0  65.4
# Республика Мордовия                                 70.3      -3.4  66.9
# Ленинградская область                               67.9      -4.9  63.0
# Кировская область                                   69.0      -3.3  65.7
# Архангельская область (кроме Ненецкого автономн...
# Пензенская область                                  70.5      -4.3  66.2
# Тюменская область (кроме Ханты-Мансийского авто...
# Республика Крым
# Томская область                                     69.2      -4.3  64.9
# Саратовская область                                 69.5      -4.5  65.0
# Республика Саха (Якутия)                            66.3      -2.6  63.7
# Республика Марий Эл                                 68.7      -4.1  64.6
# Чувашская Республика (Чувашия)                      70.0      -3.6  66.4
# Удмуртская Республика                               69.3      -3.5  65.8
# Ульяновская область                                 69.5      -3.6  65.9
# Рязанская область                                   69.2      -4.3  64.9
# Ярославская область                                 69.0      -3.8  65.2
# Костромская область                                 68.2      -4.2  64.0
# Вологодская область                                 69.0      -3.3  65.7
# Ивановская область                                  68.1      -5.5  62.6
# Брянская область                                    69.3      -4.6  64.7
# Липецкая область                                    69.3      -2.5  66.8
# Курская область                                     68.3      -3.0  65.3
# Самарская область                                   69.5      -5.0  64.5
# Ненецкий автономный округ (Архангельская область)                   60.6
# Калужская область                                   69.3      -5.0  64.3
# Республика Башкортостан                             70.0      -3.3  66.7
# Нижегородская область                               69.8      -4.7  65.1
# Омская область                                      69.4      -3.2  66.2
# Новосибирская область                               68.9      -2.6  66.3
# Республика Коми                                     67.9      -4.4  63.5
# Челябинская область                                 69.8      -5.1  64.7
# Республика Бурятия                                  66.8      -4.1  62.7
# Тульская область                                    68.5      -5.4  63.1
# Алтайский край                                      68.4      -1.8  66.6
# Свердловская область                                68.8      -5.1  63.7
# Орловская область                                   68.8      -3.2  65.6
# Смоленская область                                  68.5      -5.6  62.9
# Республика Хакасия                                  66.7      -3.9  62.8
# Владимирская область                                69.3      -5.9  63.4
# Курганская область                                  68.8      -4.3  64.5
# Красноярский край                                   68.0      -5.5  62.5
# Мурманская область                                  70.4      -5.9  64.5
# Тверская область                                    68.1      -5.6  62.5
# Оренбургская область                                69.5      -4.5  65.0
# Сахалинская область                                 66.3      -3.0  63.3
# Республика Карелия                                  68.2      -5.3  62.9
# Пермский край                                       68.1      -4.7  63.4
# Новгородская область                                67.2      -4.4  62.8
# Ульяновская область                                     -1.98  70.98
# Рязанская область                                       -2.25  70.95
# Ярославская область                                     -1.98  70.94
# Костромская область                                     -1.43  70.92
# Вологодская область                                     -1.11  70.71
# Ивановская область                                      -1.18  70.66
# Брянская область                                        -1.68  70.63
# Липецкая область                                        -2.75  70.59
# Курская область                                         -1.75  70.52
# Самарская область                                       -2.32  70.45
# Ненецкий автономный округ (Архангельская область)       -2.79  70.40
# Калужская область                                       -1.97  70.38
# Республика Башкортостан                                 -2.28  70.36
# Нижегородская область                                   -1.99  70.33
# Омская область                                          -2.00  70.32
# Новосибирская область                                   -1.93  70.32
# Республика Коми                                         -1.00  70.30
# Челябинская область                                     -1.79  70.29
# Республика Бурятия                                      -0.48  70.29
# Тульская область                                        -2.01  70.20
# Алтайский край                                          -1.42  70.19
# Свердловская область                                    -1.66  70.15
# Орловская область                                       -2.46  70.10
# Смоленская область                                      -1.79  70.10
# Республика Хакасия                                      -0.99  70.06
# Владимирская область                                    -1.84  70.03
# Курганская область                                      -1.20  69.94
# Красноярский край                                       -1.34  69.82
# Мурманская область                                      -1.94  69.81
# Тверская область                                        -1.48  69.76
# Оренбургская область                                    -2.31  69.73
# Сахалинская область                                     -0.55  69.73
# Республика Карелия                                      -1.83  69.63
# Пермский край                                           -1.73  69.59
# Новгородская область                                    -0.93  69.59
# Приморский край                                         -0.99  69.55
# Камчатский край                                         -1.30  69.27
# Республика Алтай                                        -1.14  69.15
# Псковская область                                       -1.52  69.13
# Магаданская область                                     -0.62  69.04
# Хабаровский край                                        -1.44  68.61
# Кемеровская область - Кузбасс                           -1.27  68.51
# Иркутская область                                       -1.30  68.25
# Забайкальский край                                      -0.65  68.23
# Еврейская автономная область                            -0.58  67.50
# Амурская область                                        -1.28  67.38
# Республика Тыва                                         -1.32  66.25
# Чукотский автономный округ                              -2.27  65.82

# %%
df_subjects.head(1)
# Out:
#                   overall  males  females  females_vs_males  urban  rural  \
# Россия в среднем    71.54  66.49    76.43              9.94  71.81  70.69
#
#                   urban_vs_rural  1991  1991→2000  2000  2000→2014   2014  \
# Россия в среднем            1.12  68.9       -3.6  65.3       5.63  70.93
#
#                   2014→2019   2019  2019→2020   2020
# Россия в среднем       2.41  73.34       -1.8  71.54

# %%
# create code for placing info in Wikipedia
def create_table(df, file_header, file_footer):

    def if_value(x, prec=2):
        return '-' if math.isnan(x) else f"{x:0.{prec}f}" #"{x:0.{prec}f}".format(x, prec)
    
    with open('design/' + file_header, mode='r', encoding="utf-8") as fh:
        table_header = fh.read()
    
    with open('design/' + file_footer, mode='r', encoding="utf-8") as fh:
        table_footer = fh.read()

    st = table_header
    for i in range(len(df)):
        ser = df.iloc[i]
        if ser.name == 'Россия в среднем':
            st += '\n' + '|-class=static-row-header\n' + \
                  f'|align=left|\'\'\'{ser.name}\'\'\' ' + \
                  f'|| style="text-align:center; background:#e0ffd8;"|\'\'\'{if_value(ser["overall"], 2)}\'\'\' ' + \
                  f'|| style="background:#eaf3ff;"|\'\'\'{if_value(ser["males"], 2)}\'\'\' ' + \
                  f'|| style="background:#fee7f6;"|\'\'\'{if_value(ser["females"], 2)}\'\'\' ' + \
                  f'|| style="background:#fff8dc;"|\'\'\'{if_value(ser["females_vs_males"], 2)}\'\'\' ' + \
                  f'|| style="border-left-width:2px;"|\'\'\'{if_value(ser["urban"], 2)}\'\'\' ' + \
                  f'|| \'\'\'{if_value(ser["rural"], 2)}\'\'\' ' + \
                  f'|| style="background:#fff8dc;"|\'\'\'{if_value(ser["urban_vs_rural"], 2)}\'\'\' ' + \
                  f'|| style="border-left-width:2px;"|\'\'\'{if_value(ser["1991"], 1)}\'\'\' ' + \
                  f'|| style="background:#fff8dc;"|\'\'\'{if_value(ser["1991→2000"], 1)}\'\'\' ' + \
                  f'|| \'\'\'{if_value(ser["2000"], 1)}\'\'\' ' + \
                  f'|| style="background:#fff8dc;"|\'\'\'{if_value(ser["2000→2014"], 2)}\'\'\' ' + \
                  f'|| \'\'\'{if_value(ser["2014"], 2)}\'\'\' ' + \
                  f'|| style="background:#fff8dc;"|\'\'\'{if_value(ser["2014→2019"], 2)}\'\'\' ' + \
                  f'|| \'\'\'{if_value(ser["2019"], 2)}\'\'\' ' + \
                  f'|| style="background:#fff8dc;"|\'\'\'{if_value(ser["2019→2020"], 2)}\'\'\' ' + \
                  f'|| style="text-align:center; background:#e0ffd8;"|\'\'\'{if_value(ser["2020"], 2)}\'\'\''
        else:        
            st += '\n' + '|-\n' + \
                  f'|align=left|[[{ser.name}]] ' + \
                  f'|| style="text-align:center; background:#e0ffd8;"|\'\'\'{if_value(ser["overall"], 2)}\'\'\' ' + \
                  f'|| style="background:#eaf3ff;"|{if_value(ser["males"], 2)} ' + \
                  f'|| style="background:#fee7f6;"|{if_value(ser["females"], 2)} ' + \
                  f'|| style="background:#fff8dc;"|{if_value(ser["females_vs_males"], 2)} ' + \
                  f'|| style="border-left-width:2px;"|{if_value(ser["urban"], 2)} ' + \
                  f'|| {if_value(ser["rural"], 2)} ' + \
                  f'|| style="background:#fff8dc;"|{if_value(ser["urban_vs_rural"], 2)} ' + \
                  f'|| style="border-left-width:2px;"|{if_value(ser["1991"], 1)} ' + \
                  f'|| style="background:#fff8dc;"|{if_value(ser["1991→2000"], 1)} ' + \
                  f'|| {if_value(ser["2000"], 1)} ' + \
                  f'|| style="background:#fff8dc;"|{if_value(ser["2000→2014"], 2)} ' + \
                  f'|| {if_value(ser["2014"], 2)} ' + \
                  f'|| style="background:#fff8dc;"|{if_value(ser["2014→2019"], 2)} ' + \
                  f'|| {if_value(ser["2019"], 2)} ' + \
                  f'|| style="background:#fff8dc;"|{if_value(ser["2019→2020"], 2)} ' + \
                  f'|| style="text-align:center; background:#e0ffd8;"|\'\'\'{if_value(ser["2020"], 2)}\'\'\''
    st += '\n' + table_footer
    return st

table_code = create_table(df_subjects, file_header='rosstat_header_ru.txt', file_footer='rosstat_footer_ru.txt')

# %%
# write the code to file
with open('output/Table code for Russian regions.txt', 'w', encoding="utf-8") as fh:
    fh.write(table_code)

# Naming of some regions are reqiered small manual asjustment for proper linking to Wikipedia pages of according redions.
# Ideally this should be make via dictionary - this code is not professional.

# %%
# print the code here (if it is convenient)
# print(table_code)
# print('done')

# %% [markdown]
# <br />
# <br />
# <br />
#
# #### Auxiliary table that I decided not to use

# %%
ls_attention = [
    'Архангельская область',
    'Архангельская область (кроме Ненецкого автономного округа)',
    'Ненецкий автономный округ (Архангельская область)',
    'Тюменская область',
    'Тюменская область (кроме Ханты-Мансийского автономного округа-Югры и Ямало-Ненецкого автономного округа)', 
    'Ханты-Мансийский автономный округ - Югра (Тюменская область)',
    'Ямало-Ненецкий автономный округ (Тюменская область)',
]

df_auxiliary = df.loc[ls_attention]
print(df_auxiliary.shape)
df_auxiliary.fillna(' ')
# Out:
# (7, 16)
#                                                     overall  males  females  \
# Архангельская область                                 71.35  65.71    77.03
# Архангельская область (кроме Ненецкого автономн...    71.39  65.79    77.01
# Ненецкий автономный округ (Архангельская область)     70.40  63.44    77.79
# Тюменская область                                     72.24  67.54    76.89
# Тюменская область (кроме Ханты-Мансийского авто...    71.34  66.17    76.51
# Ханты-Мансийский автономный округ - Югра (Тюмен...    72.87  68.76    76.91
# Ямало-Ненецкий автономный округ (Тюменская обла...    71.91  67.54    76.21
#
#                                                     females_vs_males  urban  \
# Архангельская область                                          11.32  72.13
# Архангельская область (кроме Ненецкого автономн...             11.22  72.11
# Ненецкий автономный округ (Архангельская область)              14.35  72.51
# Тюменская область                                               9.35  72.92
# Тюменская область (кроме Ханты-Мансийского авто...             10.34  72.38
# Ханты-Мансийский автономный округ - Югра (Тюмен...              8.15  73.06
# Ямало-Ненецкий автономный округ (Тюменская обла...              8.67  72.59
#
#                                                     rural  urban_vs_rural  \
# Архангельская область                               67.75            4.38
# Архангельская область (кроме Ненецкого автономн...  68.05            4.06
# Ненецкий автономный округ (Архангельская область)   63.73            8.78
# Тюменская область                                   69.39            3.53
# Тюменская область (кроме Ханты-Мансийского авто...  69.16            3.22
# Ханты-Мансийский автономный округ - Югра (Тюмен...  70.70            2.36
# Ямало-Ненецкий автономный округ (Тюменская обла...  68.73            3.86
#
#                                                     1991 1991→2000  2000  \
# Архангельская область                               69.1      -6.3  62.8
# Архангельская область (кроме Ненецкого автономн...
# Ненецкий автономный округ (Архангельская область)                   60.6
# Тюменская область                                   68.5      -2.6  65.9
# Тюменская область (кроме Ханты-Мансийского авто...
# Ханты-Мансийский автономный округ - Югра (Тюмен...                  65.9
# Ямало-Ненецкий автономный округ (Тюменская обла...                  66.7
#
#                                                    2000→2014   2014  \
# Архангельская область                                   7.43  70.23
# Архангельская область (кроме Ненецкого автономн...            70.20
# Ненецкий автономный округ (Архангельская область)      10.05  70.65
# Тюменская область                                        5.6  71.50
# Тюменская область (кроме Ханты-Мансийского авто...            70.32
# Ханты-Мансийский автономный округ - Югра (Тюмен...      6.37  72.27
# Ямало-Ненецкий автономный округ (Тюменская обла...      5.22  71.92
#
#                                                     2014→2019   2019  \
# Архангельская область                                    2.11  72.34
# Архангельская область (кроме Ненецкого автономн...       2.10  72.30
# Ненецкий автономный округ (Архангельская область)        2.54  73.19
# Тюменская область                                        2.54  74.04
# Тюменская область (кроме Ханты-Мансийского авто...       2.43  72.75
# Ханты-Мансийский автономный округ - Югра (Тюмен...       2.77  75.04
# Ямало-Ненецкий автономный округ (Тюменская обла...       2.26  74.18
#
#                                                     2019→2020   2020
# Архангельская область                                   -0.99  71.35
# Архангельская область (кроме Ненецкого автономн...      -0.91  71.39
# Ненецкий автономный округ (Архангельская область)       -2.79  70.40
# Тюменская область                                       -1.80  72.24
# Тюменская область (кроме Ханты-Мансийского авто...      -1.41  71.34
# Ханты-Мансийский автономный округ - Югра (Тюмен...      -2.17  72.87
# Ямало-Ненецкий автономный округ (Тюменская обла...      -2.27  71.91

# %%
# create code for placing info in Wikipedia
def create_table_auxiliary(df, file_header):

    def if_value(x, prec=2):
        return '-' if math.isnan(x) else f"{x:0.{prec}f}" #"{x:0.{prec}f}".format(x, prec)
    
    with open('design/' + file_header, mode='r', encoding="utf-8") as fh:
        table_header = fh.read()

    # st = table_header
    st = table_header
    for i in range(len(df)):
        ser = df.iloc[i]       
        st += '\n' + '|-\n' + \
              f'|align=left|[[{ser.name}]] ' + \
              f'|| style="text-align:center; background:#e0ffd8;"|\'\'\'{if_value(ser["overall"], 2)}\'\'\' ' + \
              f'|| style="background:#eaf3ff;"|{if_value(ser["males"], 2)} ' + \
              f'|| style="background:#fee7f6;"|{if_value(ser["females"], 2)} ' + \
              f'|| style="background:#fff8dc;"|{if_value(ser["females_vs_males"], 2)} ' + \
              f'|| style="border-left-width:2px;"|{if_value(ser["urban"], 2)} ' + \
              f'|| {if_value(ser["rural"], 2)} ' + \
              f'|| style="background:#fff8dc;"|{if_value(ser["urban_vs_rural"], 2)} ' + \
              f'|| style="border-left-width:2px;"|{if_value(ser["1991"], 1)} ' + \
              f'|| style="background:#fff8dc;"|{if_value(ser["1991→2000"], 1)} ' + \
              f'|| {if_value(ser["2000"], 1)} ' + \
              f'|| style="background:#fff8dc;"|{if_value(ser["2000→2014"], 2)} ' + \
              f'|| {if_value(ser["2014"], 2)} ' + \
              f'|| style="background:#fff8dc;"|{if_value(ser["2014→2019"], 2)} ' + \
              f'|| {if_value(ser["2019"], 2)} ' + \
              f'|| style="background:#fff8dc;"|{if_value(ser["2019→2020"], 2)} ' + \
              f'|| style="text-align:center; background:#e0ffd8;"|\'\'\'{if_value(ser["2020"], 2)}\'\'\''
    st += '\n' + '}}'
    return st

table_code = create_table_auxiliary(df_auxiliary, file_header='rosstat_header_ru.txt')
# print(table_code)

# %%
# write the code to file
with open('output/Table code for Russian regions -attention.txt', 'w', encoding="utf-8") as fh:
    fh.write(table_code)

# Naming of some regions are reqiered small manual asjustment for proper linking to Wikipedia pages of according redions.
# Ideally this should be make via dictionary - this code is not professional.

# %% [markdown]
# <br />
# <br />
# <br />
#
# #### Additional task - forming data for [ZipMapMaker](https://navizv.github.io/zimm/)

# %%
# create data for server of colormapcreation ZiMapMaker (https://navizv.github.io/zimm)
df_colormap = df[['2019', '2020']] \
                    .drop(index='Россия в среднем')
print(df_colormap.shape)
df_colormap.head(3)
# Out:
# (87, 2)
#                        2019   2020
# Республика Ингушетия  83.40  81.48
# Республика Дагестан   79.10  76.43
# г. Москва             78.36  76.20

# %%
def filter_data_for_zipmapmaker_regions(df, errors='raise'):
    ls_dropping = [
        'Архангельская область',
        'Тюменская область'
    ]
    
    dict_renaming = {
        'Архангельская область (кроме Ненецкого автономного округа)': 'Архангельская область (кроме АО)',
        'Ненецкий автономный округ (Архангельская область)': 'Ненецкий автономный округ',        
        'Тюменская область (кроме Ханты-Мансийского автономного округа-Югры и Ямало-Ненецкого автономного округа)': 'Тюменская область (кроме двух АО)',
        'Ханты-Мансийский автономный округ - Югра (Тюменская область)': 'Ханты-Мансийский автономный округ - Югра',
        'Ямало-Ненецкий автономный округ (Тюменская область)': 'Ямало-Ненецкий автономный округ',
    }
    
    df_return = df.drop(ls_dropping, errors=errors) \
                  .rename(index=dict_renaming, errors=errors) \
                  [['2019', '2020']] \
                  .sort_values(by='2020', ascending=False)
    df_return.index.name = 'регион России'
    return df_return
    
data_for_zipmapmaker_regions = filter_data_for_zipmapmaker_regions(df_colormap)
data_for_zipmapmaker_regions
# Out:
#                                            2019   2020
# регион России
# Республика Ингушетия                      83.40  81.48
# Республика Дагестан                       79.10  76.43
# г. Москва                                 78.36  76.20
# Карачаево-Черкесская Республика           76.21  74.82
# Кабардино-Балкарская Республика           76.46  74.37
# Республика Северная Осетия-Алания         75.75  74.08
# г. Санкт-Петербург                        76.31  73.99
# г. Севастополь                            73.53  73.58
# Республика Адыгея                         73.85  73.27
# Ставропольский край                       74.66  73.20
# Калининградская область                   73.56  72.93
# Республика Калмыкия                       74.84  72.93
# Ханты-Мансийский автономный округ - Югра  75.04  72.87
# Республика Татарстан                      75.03  72.61
# Белгородская область                      74.21  72.37
# Краснодарский край                        73.91  72.24
# Чеченская Республика                      75.88  72.11
# Ростовская область                        73.69  72.04
# Астраханская область                      73.86  72.01
# Волгоградская область                     74.07  71.98
# Воронежская область                       73.63  71.91
# Ямало-Ненецкий автономный округ           74.18  71.91
# Тамбовская область                        73.56  71.78
# Московская область                        73.86  71.67
# Республика Мордовия                       73.95  71.60
# Ленинградская область                     73.64  71.53
# Кировская область                         72.96  71.42
# Архангельская область (кроме АО)          72.30  71.39
# Пензенская область                        73.61  71.34
# Тюменская область (кроме двух АО)         72.75  71.34
# Республика Крым                           72.71  71.20
# Томская область                           72.85  71.17
# Саратовская область                       73.07  71.14
# Республика Саха (Якутия)                  73.00  71.10
# Республика Марий Эл                       72.90  71.05
# Чувашская Республика (Чувашия)            73.44  71.03
# Удмуртская Республика                     72.80  71.03
# Ульяновская область                       72.96  70.98
# Рязанская область                         73.20  70.95
# Ярославская область                       72.92  70.94
# Костромская область                       72.35  70.92
# Вологодская область                       71.82  70.71
# Ивановская область                        71.84  70.66
# Брянская область                          72.31  70.63
# Липецкая область                          73.34  70.59
# Курская область                           72.27  70.52
# Самарская область                         72.77  70.45
# Ненецкий автономный округ                 73.19  70.40
# Калужская область                         72.35  70.38
# Республика Башкортостан                   72.64  70.36
# Нижегородская область                     72.32  70.33
# Омская область                            72.32  70.32
# Новосибирская область                     72.25  70.32
# Республика Коми                           71.30  70.30
# Челябинская область                       72.08  70.29
# Республика Бурятия                        70.77  70.29
# Тульская область                          72.21  70.20
# Алтайский край                            71.61  70.19
# Свердловская область                      71.81  70.15
# Орловская область                         72.56  70.10
# Смоленская область                        71.89  70.10
# Республика Хакасия                        71.05  70.06
# Владимирская область                      71.87  70.03
# Курганская область                        71.14  69.94
# Красноярский край                         71.16  69.82
# Мурманская область                        71.75  69.81
# Тверская область                          71.24  69.76
# Оренбургская область                      72.04  69.73
# Сахалинская область                       70.28  69.73
# Республика Карелия                        71.46  69.63
# Пермский край                             71.32  69.59
# Новгородская область                      70.52  69.59
# Приморский край                           70.54  69.55
# Камчатский край                           70.57  69.27
# Республика Алтай                          70.29  69.15
# Псковская область                         70.65  69.13
# Магаданская область                       69.66  69.04
# Хабаровский край                          70.05  68.61
# Кемеровская область - Кузбасс             69.78  68.51
# Иркутская область                         69.55  68.25
# Забайкальский край                        68.88  68.23
# Еврейская автономная область              68.08  67.50
# Амурская область                          68.66  67.38
# Республика Тыва                           67.57  66.25
# Чукотский автономный округ                68.09  65.82

# %%
data_for_zipmapmaker_regions.to_csv('output/data for ZipMapMaker colormap -regions.csv', sep=';', encoding='utf-8')
print('Done')
# Out:
# Done

# %%
df.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16076/1685560713.py in <module>
# ----> 1 df.sort_values()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
def filter_regions(df_regions: 'dataframe', errors='raise'):
    """
    The function takes dataframe with regions, remove some rows and rename others.
    """
    
    ls_dropping = [
        'Центральный федеральный округ',
        'Северо-Западный федеральный округ',
        'Южный федеральный округ (по 2009 год)',
        'Южный федеральный округ (с 2010 года)',
        'Южный федеральный округ (с 29.07.2016)',
        'Северо-Кавказский федеральный округ',
        'Приволжский федеральный округ',
        'Уральский федеральный округ',
        'Сибирский федеральный округ',
        'Дальневосточный федеральный округ',
        'Крымский федеральный округ',
        'Коми-Пермяцкий округ, входящий в состав Пермского края',
        'Таймырский (Долгано-Ненецкий) автономный округ (Красноярский край)',
        'Эвенкийский автономный округ (Красноярский край)',
        'Усть-Ордынский Бурятский округ',
        'Агинский Бурятский округ (Забайкальский край)',
        'Корякский округ, входящий в состав Камчатского края',
        'Чеченская и Ингушская Республики' 
    ]

    dict_renaming = {

    }
    
    return df_regions.drop(ls_dropping, errors=errors) \
                     .rename(index=dict_renaming, errors=errors) \
                     .sort_index()
    
df = filter_regions(df)
print(df.shape)
df.head(2)

# %%
df_colormap

# %% [markdown]
# <br />
# <br />
# <br />

# %%
# # create csv-file with data of some years
# df_some_years = df_main_subjects[['1991', '2000', '2014', '2019', '2020']] \
#                     .drop(index='Россия в среднем')
# df_some_years.fillna(' ')

# df_some_years.to_csv('output/Longevity in Russian regions.csv')
# print('Done')
