# %% [markdown]
# source of data: [Instituto Nacional de Estadística: Provinces](https://www.ine.es/jaxiT3/Tabla.htm?t=1485&L=1),<br>
# Spain as a whole: [Total](https://www.ine.es/consul/serie.do?d=true&s=TM2177),
# [Males](https://www.ine.es/consul/serie.do?d=true&s=TM1449),
# [Females](https://www.ine.es/consul/serie.do?d=true&s=TM721)<br>
# wiki > [List of Spanish provinces by life expectancy](https://en.wikipedia.org/wiki/List_of_Spanish_provinces_by_life_expectancy), [Political divisions of Spain](https://en.wikipedia.org/wiki/Political_divisions_of_Spain), [Provinces of Spain](https://en.wikipedia.org/wiki/Provinces_of_Spain)<br>
# wiki > [Продолжительность жизни в провинциях Испании](https://ru.wikipedia.org/wiki/Продолжительность_жизни_в_провинциях_Испании), [Административное деление Испании](https://ru.wikipedia.org/wiki/Административное_деление_Испании), [Провинции Испании](https://ru.wikipedia.org/wiki/Провинции_Испании)<br />
# [MapChart](https://www.mapchart.net/spain.html)

# %%
import pandas as pd
from collections import namedtuple

import sys
sys.path.append("..")
import mal_moduls_private.mal_total as mal

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
pd.options.display.min_rows = 6
pd.options.display.max_rows = 50

# %%
SORT_COLUMNS = ['2024', '2023'] # used only for intermediate processing of data and does not influence to final result
SELECTED_YEAR = '2024'
CREATE_LEGEND_CODE = True

# %%
CountryGroup = namedtuple('CountryGroup', ['group_label', 'color', 'countries'])

# %% [markdown]
# docs: [standard-encodings](https://docs.python.org/3/library/codecs.html#standard-encodings)<br>
# docs: [docs: error-handlers](https://docs.python.org/3/library/codecs.html#error-handlers)
#
# <br>

# %%
# load stats about longevity per year
df = pd.read_csv('data/Life expectancy in Spain.csv', sep='\t', encoding='mbcs')  # , encoding='mbcs', encoding_errors='replace'

df.head(2)
# Out:
#      Provinces           Sex  Period  Total
# 0  02 Albacete  Both genders    2024  83.66
# 1  02 Albacete  Both genders    2023  83.61

# %%
# remove numbers before provinces names
df['Provinces'] = df['Provinces'].map(lambda st:st[3:])

# set provinces names as index
df.set_index('Provinces', drop=True, inplace=True)
df.index.name = ''

df.head()
# Out:
#                    Sex  Period  Total
#
# Albacete  Both genders    2024  83.66
# Albacete  Both genders    2023  83.61
# Albacete  Both genders    2022  82.99
# Albacete  Both genders    2021  83.21
# Albacete  Both genders    2020  81.36

# %%
df = pd.concat([df[(df.Sex == 'Both genders') & (df.Period == 2014)].Total,
                df[(df.Sex == 'Both genders') & (df.Period == 2019)].Total,
                df[(df.Sex == 'Both genders') & (df.Period == 2020)].Total,
                df[(df.Sex == 'Both genders') & (df.Period == 2021)].Total,
                df[(df.Sex == 'Both genders') & (df.Period == 2022)].Total,
                df[(df.Sex == 'Both genders') & (df.Period == 2023)].Total,
                df[(df.Sex == 'Both genders') & (df.Period == 2024)].Total,
                df[(df.Sex == 'Males') & (df.Period == 2014)].Total,
                df[(df.Sex == 'Males') & (df.Period == 2019)].Total,
                df[(df.Sex == 'Males') & (df.Period == 2023)].Total,
                df[(df.Sex == 'Males') & (df.Period == 2024)].Total,
                df[(df.Sex == 'Females') & (df.Period == 2014)].Total,
                df[(df.Sex == 'Females') & (df.Period == 2019)].Total,
                df[(df.Sex == 'Females') & (df.Period == 2023)].Total,
                df[(df.Sex == 'Females') & (df.Period == 2024)].Total
               ],
                  axis='columns',
                  keys=['2014', '2019', '2020', '2021', '2022', '2023', '2024',
                        'm_2014', 'm_2019', 'm_2023', 'm_2024', 'f_2014', 'f_2019', 'f_2023', 'f_2024'])

df.sort_values(by=SORT_COLUMNS, ascending=False, inplace=True)

print(len(df))
df.head()
# Out:
# 52
#               2014   2019   2020   2021   2022   2023   2024  m_2014  m_2019  \
#
# Salamanca    84.58  84.69  82.53  84.73  84.12  85.40  85.77   81.75   82.02
# Madrid       84.20  84.93  82.27  84.56  84.76  85.39  85.58   81.44   82.33
# Segovia      84.09  84.70  81.49  84.06  84.41  83.92  85.30   81.29   82.34
# Araba/Álava  84.38  84.76  83.59  84.31  84.13  85.07  85.02   81.76   81.80
# Valladolid   83.86  84.62  82.92  83.96  84.09  84.72  85.02   81.23   82.17
#
#              m_2023  m_2024  f_2014  f_2019  f_2023  f_2024
#
# Salamanca     82.64   83.46   87.38   87.34   88.12   87.99
# Madrid        82.92   83.07   86.59   87.19   87.51   87.74
# Segovia       81.25   82.78   87.06   87.08   86.66   87.84
# Araba/Álava   82.37   82.43   86.87   87.71   87.67   87.54
# Valladolid    82.33   82.48   86.36   86.95   86.96   87.45

# %% [markdown]
# <br />
# <br />
# <br />
#
# Just for general interest, compare life expectancy in provinces with overall life expectancy in Spain:<br>
# [all](https://www.ine.es/consul/serie.do?d=true&s=TM2177), [male](https://www.ine.es/consul/serie.do?d=true&s=TM1449), [female](https://www.ine.es/consul/serie.do?d=true&s=TM721)

# %%
df_country_all = pd.read_csv('data/Life expectancy in Spain as a whole -all.csv',
                             sep='\t', usecols=['PERIOD', 'VALUE'], index_col='PERIOD').round(3)
ser_country_all = df_country_all.loc[:, 'VALUE'].loc[[2014, 2019, 2020, 2021, 2022, 2023, 2024]]
ser_country_all.index = ser_country_all.index.map(lambda year: str(year))

df_country_m = pd.read_csv('data/Life expectancy in Spain as a whole -male.csv',
                             sep='\t', usecols=['PERIOD', 'VALUE'], index_col='PERIOD').round(3)
ser_country_m = df_country_m.loc[:, 'VALUE'].loc[[2014, 2019, 2023, 2024]]
ser_country_m.index = ser_country_m.index.map(lambda year: f"m_{year}")

df_country_f = pd.read_csv('data/Life expectancy in Spain as a whole -female.csv',
                             sep='\t', usecols=['PERIOD', 'VALUE'], index_col='PERIOD').round(3)

ser_country_f = df_country_f.loc[:, 'VALUE'].loc[[2014, 2019, 2023, 2024]]
ser_country_f.index = ser_country_f.index.map(lambda year: f"f_{year}")

ser_country = pd.concat([ser_country_all, ser_country_m, ser_country_f])
ser_country.index.name = ''
ser_country.name = 'Spain'

pd.DataFrame(ser_country).T
# Out:
#          2014    2019    2020    2021    2022    2023   2024  m_2014  m_2019  \
# Spain  82.906  83.534  82.284  83.026  83.081  83.774  84.01  80.096  80.783
#
#        m_2023  m_2024  f_2014  f_2019  f_2023  f_2024
# Spain  81.112  81.385  85.631  86.195  86.339  86.528

# %% [markdown]
# <br />

# %%
# Some inner statistics for interest:
mal.min_and_max_values(df.loc[:, '2014':'2024'], row_center=ser_country.loc['2014':'2024'], nmb=3, max_lng=11)
# Out:
# Number of records: 52
# <style type="text/css">
# #T_3c715_row0_col0, #T_3c715_row0_col1, #T_3c715_row0_col2, #T_3c715_row0_col3, #T_3c715_row0_col4, #T_3c715_row0_col5, #T_3c715_row0_col6, #T_3c715_row1_col0, #T_3c715_row1_col1, #T_3c715_row1_col2, #T_3c715_row1_col3, #T_3c715_row1_col4, #T_3c715_row1_col5, #T_3c715_row1_col6, #T_3c715_row2_col0, #T_3c715_row2_col1, #T_3c715_row2_col2, #T_3c715_row2_col3, #T_3c715_row2_col4, #T_3c715_row2_col5, #T_3c715_row2_col6, #T_3c715_row3_col0, #T_3c715_row3_col1, #T_3c715_row3_col2, #T_3c715_row3_col3, #T_3c715_row3_col4, #T_3c715_row3_col5, #T_3c715_row3_col6, #T_3c715_row4_col0, #T_3c715_row4_col1, #T_3c715_row4_col2, #T_3c715_row4_col3, #T_3c715_row4_col4, #T_3c715_row4_col5, #T_3c715_row4_col6, #T_3c715_row5_col0, #T_3c715_row5_col1, #T_3c715_row5_col2, #T_3c715_row5_col3, #T_3c715_row5_col4, #T_3c715_row5_col5, #T_3c715_row5_col6, #T_3c715_row6_col0, #T_3c715_row6_col1, #T_3c715_row6_col2, #T_3c715_row6_col3, #T_3c715_row6_col4, #T_3c715_row6_col5, #T_3c715_row6_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_3c715">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c715_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_3c715_level0_col1" class="col_heading level0 col1" >2019</th>
#       <th id="T_3c715_level0_col2" class="col_heading level0 col2" >2020</th>
#       <th id="T_3c715_level0_col3" class="col_heading level0 col3" >2021</th>
#       <th id="T_3c715_level0_col4" class="col_heading level0 col4" >2022</th>
#       <th id="T_3c715_level0_col5" class="col_heading level0 col5" >2023</th>
#       <th id="T_3c715_level0_col6" class="col_heading level0 col6" >2024</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c715_level0_row0" class="row_heading level0 row0" >max</th>
#       <td id="T_3c715_row0_col0" class="data row0 col0" >84.58 -Salamanca</td>
#       <td id="T_3c715_row0_col1" class="data row0 col1" >84.93 -Madrid</td>
#       <td id="T_3c715_row0_col2" class="data row0 col2" >83.59 -Araba/Álava</td>
#       <td id="T_3c715_row0_col3" class="data row0 col3" >84.73 -Salamanca</td>
#       <td id="T_3c715_row0_col4" class="data row0 col4" >84.76 -Madrid</td>
#       <td id="T_3c715_row0_col5" class="data row0 col5" >85.4 -Salamanca</td>
#       <td id="T_3c715_row0_col6" class="data row0 col6" >85.77 -Salamanca</td>
#     </tr>
#     <tr>
#       <th id="T_3c715_level0_row1" class="row_heading level0 row1" >max_2</th>
#       <td id="T_3c715_row1_col0" class="data row1 col0" >84.38 -Araba/Álava</td>
#       <td id="T_3c715_row1_col1" class="data row1 col1" >84.76 -Araba/Álava</td>
#       <td id="T_3c715_row1_col2" class="data row1 col2" >83.43 -Coruña, A</td>
#       <td id="T_3c715_row1_col3" class="data row1 col3" >84.56 -Madrid</td>
#       <td id="T_3c715_row1_col4" class="data row1 col4" >84.41 -Segovia</td>
#       <td id="T_3c715_row1_col5" class="data row1 col5" >85.39 -Madrid</td>
#       <td id="T_3c715_row1_col6" class="data row1 col6" >85.58 -Madrid</td>
#     </tr>
#     <tr>
#       <th id="T_3c715_level0_row2" class="row_heading level0 row2" >max_3</th>
#       <td id="T_3c715_row2_col0" class="data row2 col0" >84.36 -Guadalajara</td>
#       <td id="T_3c715_row2_col1" class="data row2 col1" >84.73 -Guadalajara</td>
#       <td id="T_3c715_row2_col2" class="data row2 col2" >83.4 -Pontevedra</td>
#       <td id="T_3c715_row2_col3" class="data row2 col3" >84.55 -Burgos</td>
#       <td id="T_3c715_row2_col4" class="data row2 col4" >84.13 -Araba/Álava</td>
#       <td id="T_3c715_row2_col5" class="data row2 col5" >85.15 -Zamora</td>
#       <td id="T_3c715_row2_col6" class="data row2 col6" >85.3 -Segovia</td>
#     </tr>
#     <tr>
#       <th id="T_3c715_level0_row3" class="row_heading level0 row3" >Spain</th>
#       <td id="T_3c715_row3_col0" class="data row3 col0" > – 82.91 –</td>
#       <td id="T_3c715_row3_col1" class="data row3 col1" > – 83.53 –</td>
#       <td id="T_3c715_row3_col2" class="data row3 col2" > – 82.28 –</td>
#       <td id="T_3c715_row3_col3" class="data row3 col3" > – 83.03 –</td>
#       <td id="T_3c715_row3_col4" class="data row3 col4" > – 83.08 –</td>
#       <td id="T_3c715_row3_col5" class="data row3 col5" > – 83.77 –</td>
#       <td id="T_3c715_row3_col6" class="data row3 col6" > – 84.01 –</td>
#     </tr>
#     <tr>
#       <th id="T_3c715_level0_row4" class="row_heading level0 row4" >min_3</th>
#       <td id="T_3c715_row4_col0" class="data row4 col0" >81.17 -Cádiz</td>
#       <td id="T_3c715_row4_col1" class="data row4 col1" >81.71 -Cádiz</td>
#       <td id="T_3c715_row4_col2" class="data row4 col2" >80.36 -Ciudad Real</td>
#       <td id="T_3c715_row4_col3" class="data row4 col3" >80.61 -Almería</td>
#       <td id="T_3c715_row4_col4" class="data row4 col4" >81.44 -Cádiz</td>
#       <td id="T_3c715_row4_col5" class="data row4 col5" >81.81 -Almería</td>
#       <td id="T_3c715_row4_col6" class="data row4 col6" >82.42 -Huelva</td>
#     </tr>
#     <tr>
#       <th id="T_3c715_level0_row5" class="row_heading level0 row5" >min_2</th>
#       <td id="T_3c715_row5_col0" class="data row5 col0" >80.03 -Melilla</td>
#       <td id="T_3c715_row5_col1" class="data row5 col1" >80.67 -Melilla</td>
#       <td id="T_3c715_row5_col2" class="data row5 col2" >79.14 -Ceuta</td>
#       <td id="T_3c715_row5_col3" class="data row5 col3" >79.72 -Melilla</td>
#       <td id="T_3c715_row5_col4" class="data row5 col4" >81.31 -Almería</td>
#       <td id="T_3c715_row5_col5" class="data row5 col5" >81.61 -Melilla</td>
#       <td id="T_3c715_row5_col6" class="data row5 col6" >82.1 -Almería</td>
#     </tr>
#     <tr>
#       <th id="T_3c715_level0_row6" class="row_heading level0 row6" >min</th>
#       <td id="T_3c715_row6_col0" class="data row6 col0" >79.82 -Ceuta</td>
#       <td id="T_3c715_row6_col1" class="data row6 col1" >80.42 -Ceuta</td>
#       <td id="T_3c715_row6_col2" class="data row6 col2" >78.82 -Melilla</td>
#       <td id="T_3c715_row6_col3" class="data row6 col3" >78.3 -Ceuta</td>
#       <td id="T_3c715_row6_col4" class="data row6 col4" >79.71 -Ceuta</td>
#       <td id="T_3c715_row6_col5" class="data row6 col5" >81.11 -Ceuta</td>
#       <td id="T_3c715_row6_col6" class="data row6 col6" >81.6 -Ceuta</td>
#     </tr>
#   </tbody>
# </table>

# %%
mal.min_and_max_values(df.loc[:, 'm_2014':'f_2024'], row_center=ser_country.loc['m_2014':'f_2024'], nmb=3, max_lng=11)
# Out:
# Number of records: 52
# <style type="text/css">
# #T_05b82_row0_col0, #T_05b82_row0_col1, #T_05b82_row0_col2, #T_05b82_row0_col3, #T_05b82_row0_col4, #T_05b82_row0_col5, #T_05b82_row0_col6, #T_05b82_row0_col7, #T_05b82_row1_col0, #T_05b82_row1_col1, #T_05b82_row1_col2, #T_05b82_row1_col3, #T_05b82_row1_col4, #T_05b82_row1_col5, #T_05b82_row1_col6, #T_05b82_row1_col7, #T_05b82_row2_col0, #T_05b82_row2_col1, #T_05b82_row2_col2, #T_05b82_row2_col3, #T_05b82_row2_col4, #T_05b82_row2_col5, #T_05b82_row2_col6, #T_05b82_row2_col7, #T_05b82_row3_col0, #T_05b82_row3_col1, #T_05b82_row3_col2, #T_05b82_row3_col3, #T_05b82_row3_col4, #T_05b82_row3_col5, #T_05b82_row3_col6, #T_05b82_row3_col7, #T_05b82_row4_col0, #T_05b82_row4_col1, #T_05b82_row4_col2, #T_05b82_row4_col3, #T_05b82_row4_col4, #T_05b82_row4_col5, #T_05b82_row4_col6, #T_05b82_row4_col7, #T_05b82_row5_col0, #T_05b82_row5_col1, #T_05b82_row5_col2, #T_05b82_row5_col3, #T_05b82_row5_col4, #T_05b82_row5_col5, #T_05b82_row5_col6, #T_05b82_row5_col7, #T_05b82_row6_col0, #T_05b82_row6_col1, #T_05b82_row6_col2, #T_05b82_row6_col3, #T_05b82_row6_col4, #T_05b82_row6_col5, #T_05b82_row6_col6, #T_05b82_row6_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_05b82">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05b82_level0_col0" class="col_heading level0 col0" >m_2014</th>
#       <th id="T_05b82_level0_col1" class="col_heading level0 col1" >m_2019</th>
#       <th id="T_05b82_level0_col2" class="col_heading level0 col2" >m_2023</th>
#       <th id="T_05b82_level0_col3" class="col_heading level0 col3" >m_2024</th>
#       <th id="T_05b82_level0_col4" class="col_heading level0 col4" >f_2014</th>
#       <th id="T_05b82_level0_col5" class="col_heading level0 col5" >f_2019</th>
#       <th id="T_05b82_level0_col6" class="col_heading level0 col6" >f_2023</th>
#       <th id="T_05b82_level0_col7" class="col_heading level0 col7" >f_2024</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05b82_level0_row0" class="row_heading level0 row0" >max</th>
#       <td id="T_05b82_row0_col0" class="data row0 col0" >81.94 -Guadalajara</td>
#       <td id="T_05b82_row0_col1" class="data row0 col1" >82.67 -Guadalajara</td>
#       <td id="T_05b82_row0_col2" class="data row0 col2" >82.92 -Madrid</td>
#       <td id="T_05b82_row0_col3" class="data row0 col3" >83.46 -Salamanca</td>
#       <td id="T_05b82_row0_col4" class="data row0 col4" >87.38 -Salamanca</td>
#       <td id="T_05b82_row0_col5" class="data row0 col5" >87.71 -Araba/Álava</td>
#       <td id="T_05b82_row0_col6" class="data row0 col6" >88.15 -Soria</td>
#       <td id="T_05b82_row0_col7" class="data row0 col7" >87.99 -Salamanca</td>
#     </tr>
#     <tr>
#       <th id="T_05b82_level0_row1" class="row_heading level0 row1" >max_2</th>
#       <td id="T_05b82_row1_col0" class="data row1 col0" >81.76 -Araba/Álava</td>
#       <td id="T_05b82_row1_col1" class="data row1 col1" >82.34 -Segovia</td>
#       <td id="T_05b82_row1_col2" class="data row1 col2" >82.64 -Salamanca</td>
#       <td id="T_05b82_row1_col3" class="data row1 col3" >83.07 -Madrid</td>
#       <td id="T_05b82_row1_col4" class="data row1 col4" >87.27 -Soria</td>
#       <td id="T_05b82_row1_col5" class="data row1 col5" >87.63 -Burgos</td>
#       <td id="T_05b82_row1_col6" class="data row1 col6" >88.12 -Salamanca</td>
#       <td id="T_05b82_row1_col7" class="data row1 col7" >87.84 -Segovia</td>
#     </tr>
#     <tr>
#       <th id="T_05b82_level0_row2" class="row_heading level0 row2" >max_3</th>
#       <td id="T_05b82_row2_col0" class="data row2 col0" >81.75 -Salamanca</td>
#       <td id="T_05b82_row2_col1" class="data row2 col1" >82.33 -Madrid</td>
#       <td id="T_05b82_row2_col2" class="data row2 col2" >82.52 -Guadalajara</td>
#       <td id="T_05b82_row2_col3" class="data row2 col3" >82.78 -Segovia</td>
#       <td id="T_05b82_row2_col4" class="data row2 col4" >87.06 -Segovia</td>
#       <td id="T_05b82_row2_col5" class="data row2 col5" >87.34 -Salamanca</td>
#       <td id="T_05b82_row2_col6" class="data row2 col6" >87.96 -Zamora</td>
#       <td id="T_05b82_row2_col7" class="data row2 col7" >87.74 -Madrid</td>
#     </tr>
#     <tr>
#       <th id="T_05b82_level0_row3" class="row_heading level0 row3" >Spain</th>
#       <td id="T_05b82_row3_col0" class="data row3 col0" > – 80.1 –</td>
#       <td id="T_05b82_row3_col1" class="data row3 col1" > – 80.78 –</td>
#       <td id="T_05b82_row3_col2" class="data row3 col2" > – 81.11 –</td>
#       <td id="T_05b82_row3_col3" class="data row3 col3" > – 81.39 –</td>
#       <td id="T_05b82_row3_col4" class="data row3 col4" > – 85.63 –</td>
#       <td id="T_05b82_row3_col5" class="data row3 col5" > – 86.19 –</td>
#       <td id="T_05b82_row3_col6" class="data row3 col6" > – 86.34 –</td>
#       <td id="T_05b82_row3_col7" class="data row3 col7" > – 86.53 –</td>
#     </tr>
#     <tr>
#       <th id="T_05b82_level0_row4" class="row_heading level0 row4" >min_3</th>
#       <td id="T_05b82_row4_col0" class="data row4 col0" >78.44 -Cádiz</td>
#       <td id="T_05b82_row4_col1" class="data row4 col1" >78.98 -Cádiz</td>
#       <td id="T_05b82_row4_col2" class="data row4 col2" >79.24 -Cádiz</td>
#       <td id="T_05b82_row4_col3" class="data row4 col3" >79.63 -Ceuta</td>
#       <td id="T_05b82_row4_col4" class="data row4 col4" >83.9 -Cádiz</td>
#       <td id="T_05b82_row4_col5" class="data row4 col5" >84.45 -Cádiz</td>
#       <td id="T_05b82_row4_col6" class="data row4 col6" >84.34 -Huelva</td>
#       <td id="T_05b82_row4_col7" class="data row4 col7" >84.94 -Santa Cruz…</td>
#     </tr>
#     <tr>
#       <th id="T_05b82_level0_row5" class="row_heading level0 row5" >min_2</th>
#       <td id="T_05b82_row5_col0" class="data row5 col0" >77.67 -Melilla</td>
#       <td id="T_05b82_row5_col1" class="data row5 col1" >78.36 -Ceuta</td>
#       <td id="T_05b82_row5_col2" class="data row5 col2" >79.11 -Almería</td>
#       <td id="T_05b82_row5_col3" class="data row5 col3" >79.57 -Huelva</td>
#       <td id="T_05b82_row5_col4" class="data row5 col4" >83.32 -Ceuta</td>
#       <td id="T_05b82_row5_col5" class="data row5 col5" >83.14 -Melilla</td>
#       <td id="T_05b82_row5_col6" class="data row5 col6" >83.45 -Melilla</td>
#       <td id="T_05b82_row5_col7" class="data row5 col7" >84.9 -Almería</td>
#     </tr>
#     <tr>
#       <th id="T_05b82_level0_row6" class="row_heading level0 row6" >min</th>
#       <td id="T_05b82_row6_col0" class="data row6 col0" >76.62 -Ceuta</td>
#       <td id="T_05b82_row6_col1" class="data row6 col1" >78.17 -Melilla</td>
#       <td id="T_05b82_row6_col2" class="data row6 col2" >78.78 -Ceuta</td>
#       <td id="T_05b82_row6_col3" class="data row6 col3" >79.43 -Almería</td>
#       <td id="T_05b82_row6_col4" class="data row6 col4" >82.41 -Melilla</td>
#       <td id="T_05b82_row6_col5" class="data row6 col5" >82.57 -Ceuta</td>
#       <td id="T_05b82_row6_col6" class="data row6 col6" >83.43 -Ceuta</td>
#       <td id="T_05b82_row6_col7" class="data row6 col7" >83.51 -Ceuta</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <br />
# <br />

# %%
# renaming of provinces according to requirement of the online-service 'MapChart'
df.rename(index={
    'Alicante/Alacant' : 'Alicante',
    'Araba/Álava' : 'Álava',
    'Balears, Illes' : 'Islas_Baleares',
    'Bizkaia' : 'Vizcaya',
    'Castellón/Castelló' : 'Castellón',
    'Ciudad Real' : 'Ciudad_Real',
    'Coruña, A' : 'A_Coruña',
    'Palmas, Las' : 'Las_Palmas',
    'Rioja, La' : 'La_Rioja',
    'Santa Cruz de Tenerife' : 'Santa_Cruz_de_Tenerife',
    'Valencia/València' : 'Valencia'
}, inplace=True)

df.head(3)
# Out:
#             2014   2019   2020   2021   2022   2023   2024  m_2014  m_2019  \
#
# Salamanca  84.58  84.69  82.53  84.73  84.12  85.40  85.77   81.75   82.02
# Madrid     84.20  84.93  82.27  84.56  84.76  85.39  85.58   81.44   82.33
# Segovia    84.09  84.70  81.49  84.06  84.41  83.92  85.30   81.29   82.34
#
#            m_2023  m_2024  f_2014  f_2019  f_2023  f_2024
#
# Salamanca   82.64   83.46   87.38   87.34   88.12   87.99
# Madrid      82.92   83.07   86.59   87.19   87.51   87.74
# Segovia     81.25   82.78   87.06   87.08   86.66   87.84

# %% [markdown]
# <br />
# <br />
#
# <h4>Overall statistics</h4>

# %%
dd_legend_main = {
    '85.75–85.99' : '006a00',
    '85.50–85.74' : '007800',
    '85.25–85.49' : '008800',
    '85.00–85.24' : '009800',
    '84.75–84.99' : '00a700',
    '84.50–84.74' : '00b800',
    '84.25–84.49' : '00cb00',
    '84.00–84.24' : '00e000',
    '83.75–83.99' : '00f000',
    '83.50–83.74' : '00ff00',
    '83.25–83.49' : '88ff00',
    '83.00–83.24' : 'b8ff00',
    '82.75–82.99' : 'deff00',
    '82.50–82.74' : 'ffff00',
    '82.25–82.49' : 'ffef00',
    '82.00–82.24' : 'ffe000',
    '81.75–81.99' : 'ffce00',
    '81.50–81.74' : 'ffbc00',
    '81.25–81.49' : 'ffac00',
    '81.00–81.24' : 'ff9c00',
    '80.75–80.99' : 'ff8700',
    '80.50–80.74' : 'ff7400',
    '80.25–80.49' : 'ff5200',
    '80.00–80.24' : 'ff0000',
    '79.75–79.99' : 'e10000',
	'79.50–79.74' : 'c70000',
	'79.25–79.49' : 'af0000',
	'79.00–79.24' : '9e0000',
	'78.75–78.99' : '8b0000',
	'78.50–78.74' : '790000',
	'78.25–78.49' : '670000',
	'78.00–78.24' : '580000'
}

def fn_create_legend_code(dd_legend):
    for k, v in dd_legend.items():
        print(f"{{{{Legend|#{v}|{k}}}}}")  

if CREATE_LEGEND_CODE:
    fn_create_legend_code(dd_legend_main)
# Out:
# {{Legend|#006a00|85.75–85.99}}
# {{Legend|#007800|85.50–85.74}}
# {{Legend|#008800|85.25–85.49}}
# {{Legend|#009800|85.00–85.24}}
# {{Legend|#00a700|84.75–84.99}}
# {{Legend|#00b800|84.50–84.74}}
# {{Legend|#00cb00|84.25–84.49}}
# {{Legend|#00e000|84.00–84.24}}
# {{Legend|#00f000|83.75–83.99}}
# {{Legend|#00ff00|83.50–83.74}}
# {{Legend|#88ff00|83.25–83.49}}
# {{Legend|#b8ff00|83.00–83.24}}
# {{Legend|#deff00|82.75–82.99}}
# {{Legend|#ffff00|82.50–82.74}}
# {{Legend|#ffef00|82.25–82.49}}
# {{Legend|#ffe000|82.00–82.24}}
# {{Legend|#ffce00|81.75–81.99}}
# {{Legend|#ffbc00|81.50–81.74}}
# {{Legend|#ffac00|81.25–81.49}}
# {{Legend|#ff9c00|81.00–81.24}}
# {{Legend|#ff8700|80.75–80.99}}
# {{Legend|#ff7400|80.50–80.74}}
# {{Legend|#ff5200|80.25–80.49}}
# {{Legend|#ff0000|80.00–80.24}}
# {{Legend|#e10000|79.75–79.99}}
# {{Legend|#c70000|79.50–79.74}}
# {{Legend|#af0000|79.25–79.49}}
# {{Legend|#9e0000|79.00–79.24}}
# {{Legend|#8b0000|78.75–78.99}}
# {{Legend|#790000|78.50–78.74}}
# {{Legend|#670000|78.25–78.49}}
# {{Legend|#580000|78.00–78.24}}

# %%
def filter_df(df, selected_year=SELECTED_YEAR):
    filtered_df = df.loc[:, [selected_year]]   \
                    .sort_values(by=selected_year, ascending=False) \
                    .dropna()

    filtered_df['group_label'] = filtered_df[selected_year].map(lambda x: f"{x * 8 // 2 / 4:.2f}–{x * 8 // 2 / 4 + 0.24:.2f}")
    
    filtered_df['group_label'] = filtered_df['group_label']
    
    min_value = filtered_df[selected_year].min()
    max_value = filtered_df[selected_year].max()
    
    print(f"           ——— {selected_year} ———")
    print(f"Range: {min_value:.2f} – {max_value:.2f}   " +
          f"({filtered_df[selected_year].idxmin()} – {filtered_df[selected_year].idxmax()})")
    print(f"Number of groups: {filtered_df['group_label'].nunique()}")
    print(f"Number of values: {len(filtered_df)}")

    return filtered_df

df_sel_year = filter_df(df, SELECTED_YEAR)
df_sel_year
# Out:
#            ——— 2024 ———
# Range: 81.60 – 85.77   (Ceuta – Salamanca)
# Number of groups: 16
# Number of values: 52
#             2024  group_label
#
# Salamanca  85.77  85.75–85.99
# Madrid     85.58  85.50–85.74
# Segovia    85.30  85.25–85.49
# ...          ...          ...
# Huelva     82.42  82.25–82.49
# Almería    82.10  82.00–82.24
# Ceuta      81.60  81.50–81.74
#
# [52 rows x 2 columns]

# %%
# df_sel_year['group_label'].replace({'85.50–85.74': '85.5⩾',
#                                     '85.75–85.99': '85.5⩾'}, inplace=True)

# df_sel_year

# %%
def extract_indexes(subdf, dd_legend):
    group_label = subdf['group_label'].iloc[0]
    countries = subdf.index.to_list()
    color = (dd_legend[group_label])
    
    ls_grouping.append(CountryGroup(group_label=group_label, countries=countries, color=color))

    return pd.Series([color, countries], index=['color', 'regions'])


ls_grouping = []
df_grouped = df_sel_year.groupby(['group_label']).apply(extract_indexes, dd_legend = dd_legend_main).loc[::-1]
                        # .rename(index={'78.0–79.99': '<80'})

# if ls_grouping[0].group_label == '78.0–79.99':
#     ls_grouping[0] = ls_grouping[0]._replace(group_label = '<80')

df_grouped
# Out:
#               color                                            regions
# group_label
# 85.75–85.99  006a00                                        [Salamanca]
# 85.50–85.74  007800                                           [Madrid]
# 85.25–85.49  008800                                          [Segovia]
# 85.00–85.24  009800                                [Álava, Valladolid]
# 84.50–84.74  00b800    [Navarra, Vizcaya, Guadalajara, Burgos, Zamora]
# 84.25–84.49  00cb00  [Soria, Gipuzkoa, Barcelona, Ávila, Toledo, Za...
# 84.00–84.24  00e000                     [Pontevedra, A_Coruña, Huesca]
# 83.75–83.99  00f000  [Lugo, Lleida, León, La_Rioja, Teruel, Cantabr...
# 83.50–83.74  00ff00    [Palencia, Cuenca, Albacete, Cáceres, Alicante]
# 83.25–83.49  88ff00  [Islas_Baleares, Granada, Murcia, Tarragona, A...
# 83.00–83.24  b8ff00                     [Córdoba, Málaga, Ciudad_Real]
# 82.75–82.99  deff00            [Santa_Cruz_de_Tenerife, Badajoz, Jaén]
# 82.50–82.74  ffff00              [Sevilla, Las_Palmas, Melilla, Cádiz]
# 82.25–82.49  ffef00                                           [Huelva]
# 82.00–82.24  ffe000                                          [Almería]
# 81.50–81.74  ffbc00                                            [Ceuta]

# %%
def create_map_code(ls_grouping, title='', legend_color='#000'):  # (ls_grouping, title='', legend_color='#000'):
    false, true = False, True

    jo = {
        "groups": { },
        "title": title,
        "hidden": [],
        "background": "#ffffff",
        "borders": "#000",
        "legendFont": "Century Gothic",
        "legendFontColor": "#000",
        "legendBorderColor": "#00000000",
        "legendBgColor": "#00000000",
        "legendWidth": 100,
        "legendBoxShape": "square",
        "areBordersShown": true,
        "defaultColor": "#d1dbdd",
        "labelsColor": "#6a0707",
        "labelsFont": "Arial",
        "strokeWidth": "medium",
        "areLabelsShown": true,
        "uncoloredScriptColor": "#ffff33",
        "v6": true,
        "page": "spain",
        "levelsVisibility": [
            "show",
            "hide",
            "transparent"
        ],
        "legendPosition": "custom",
        "legendX": 150,
        "legendY": 320,
        "legendSize": "large",
        "legendTranslateX": "0.00",
        "legendStatus": "show",
        "scalingPatterns": true,
        "legendRowsSameColor": true,
        "legendColumnCount": 1
    }

    for group_label, color, regions in ls_grouping[::-1]:
        jo["groups"][f"#{color}"] = {"label": group_label.replace('.00', '.0').replace('.25', '¼').replace('.50', '.5').replace('.75', '¾').replace('–', ' - '),
                                     "paths": [region.replace(' ', '_') for region in regions]}       

    return jo


jo = create_map_code(ls_grouping, title=f'{SELECTED_YEAR}', legend_color='#333333')

pretty_jo = json.dumps(jo, indent=2, ensure_ascii=False)

with open(f"output/map_JSON -{SELECTED_YEAR}.txt", 'w', encoding="utf-8") as fh:
    fh.write(pretty_jo)

# %% [markdown]
# <br />
# <br />
#
# <h4>Statistics for males</h4>

# %%
dd_legend_male = {
    '83.0⩾' : '020f19',
	'82.75–82.99' : '042136',
	'82.50–82.74' : '062f4c',
	'82.25–82.49' : '073a5e',
	'82.00–82.24' : '08436e',
	'81.75–81.99' : '0a4e7f',
	'81.50–81.74' : '0b578d',
	'81.25–81.49' : '0c609c',
	'81.00–81.24' : '0d68a9',
	'80.75–80.99' : '0e71b7',
	'80.50–80.74' : '107ac6',
	'80.25–80.49' : '1182d4',
	'80.00–80.24' : '128be1',
	'79.75–79.99' : '1c95ec',
	'79.50–79.74' : '2e9eee',
	'79.25–79.49' : '40a6ef',
	'79.00–79.24' : '51aef0',
	'78.75–78.99' : '61b5f2',
	'78.50–78.74' : '6ebcf3',
	'78.25–78.49' : '80c4f4',
	'78.00–78.24' : '92ccf6',
	'77.75–77.99' : 'a2d4f7',
	'77.50–77.74' : 'b3dbf8',
	'77.25–77.49' : 'c2e3fa',
	'77.00–77.24' : 'd4ebfb',
	'76.75–76.99' : 'e4f2fc',
	'76.50–76.74' : 'edf7fd',
	'76.25–76.49' : 'f4fafe',
	'76.00–76.24' : 'f8fbfe'
}

if CREATE_LEGEND_CODE:
    fn_create_legend_code(dd_legend_male)
# Out:
# {{Legend|#020f19|83.0⩾}}
# {{Legend|#042136|82.75–82.99}}
# {{Legend|#062f4c|82.50–82.74}}
# {{Legend|#073a5e|82.25–82.49}}
# {{Legend|#08436e|82.00–82.24}}
# {{Legend|#0a4e7f|81.75–81.99}}
# {{Legend|#0b578d|81.50–81.74}}
# {{Legend|#0c609c|81.25–81.49}}
# {{Legend|#0d68a9|81.00–81.24}}
# {{Legend|#0e71b7|80.75–80.99}}
# {{Legend|#107ac6|80.50–80.74}}
# {{Legend|#1182d4|80.25–80.49}}
# {{Legend|#128be1|80.00–80.24}}
# {{Legend|#1c95ec|79.75–79.99}}
# {{Legend|#2e9eee|79.50–79.74}}
# {{Legend|#40a6ef|79.25–79.49}}
# {{Legend|#51aef0|79.00–79.24}}
# {{Legend|#61b5f2|78.75–78.99}}
# {{Legend|#6ebcf3|78.50–78.74}}
# {{Legend|#80c4f4|78.25–78.49}}
# {{Legend|#92ccf6|78.00–78.24}}
# {{Legend|#a2d4f7|77.75–77.99}}
# {{Legend|#b3dbf8|77.50–77.74}}
# {{Legend|#c2e3fa|77.25–77.49}}
# {{Legend|#d4ebfb|77.00–77.24}}
# {{Legend|#e4f2fc|76.75–76.99}}
# {{Legend|#edf7fd|76.50–76.74}}
# {{Legend|#f4fafe|76.25–76.49}}
# {{Legend|#f8fbfe|76.00–76.24}}

# %%
df_sel_year = filter_df(df, f"m_{SELECTED_YEAR}")
df_sel_year
# Out:
#            ——— m_2024 ———
# Range: 79.43 – 83.46   (Almería – Salamanca)
# Number of groups: 16
# Number of values: 52
#            m_2024  group_label
#
# Salamanca   83.46  83.25–83.49
# Madrid      83.07  83.00–83.24
# Segovia     82.78  82.75–82.99
# ...           ...          ...
# Ceuta       79.63  79.50–79.74
# Huelva      79.57  79.50–79.74
# Almería     79.43  79.25–79.49
#
# [52 rows x 2 columns]

# %%
df_sel_year['group_label'] = df_sel_year['group_label'].replace({'83.00–83.24': '83.0⩾',
                                                                 '83.25–83.49': '83.0⩾'})

df_sel_year
# Out:
#            m_2024  group_label
#
# Salamanca   83.46        83.0⩾
# Madrid      83.07        83.0⩾
# Segovia     82.78  82.75–82.99
# ...           ...          ...
# Ceuta       79.63  79.50–79.74
# Huelva      79.57  79.50–79.74
# Almería     79.43  79.25–79.49
#
# [52 rows x 2 columns]

# %%
ls_grouping = []
df_grouped = df_sel_year.groupby(['group_label']).apply(extract_indexes, dd_legend = dd_legend_male).loc[::-1]

df_grouped
# Out:
#               color                                            regions
# group_label
# 83.0⩾        020f19                                [Salamanca, Madrid]
# 82.75–82.99  042136                                          [Segovia]
# 82.50–82.74  062f4c                               [Guadalajara, Soria]
# 82.25–82.49  073a5e                                [Valladolid, Álava]
# 81.75–81.99  0a4e7f  [Ávila, Navarra, Vizcaya, Burgos, Zamora, Tole...
# 81.50–81.74  0b578d                       [Zaragoza, Gipuzkoa, Teruel]
# 81.25–81.49  0c609c                     [Lleida, La_Rioja, Pontevedra]
# 81.00–81.24  0d68a9  [Girona, Ourense, Alicante, A_Coruña, Cuenca, ...
# 80.75–80.99  0e71b7    [Palencia, Murcia, Tarragona, Cáceres, Granada]
# 80.50–80.74  107ac6  [Valencia, Santa_Cruz_de_Tenerife, Málaga, Cas...
# 80.25–80.49  1182d4                    [Córdoba, Las_Palmas, Asturias]
# 80.00–80.24  128be1                  [Jaén, Melilla, Badajoz, Sevilla]
# 79.75–79.99  1c95ec                                            [Cádiz]
# 79.50–79.74  2e9eee                                    [Ceuta, Huelva]
# 79.25–79.49  40a6ef                                          [Almería]

# %%
if SELECTED_YEAR not in ['2020', '2021', '2022']:
    jo = create_map_code(ls_grouping, title=f'{SELECTED_YEAR}: ♂', legend_color='#333333')  # legend_color='#0000bf'
    
    pretty_jo = json.dumps(jo, indent=2, ensure_ascii=False)
    
    with open(f"output/map_JSON -{SELECTED_YEAR}, male.txt", 'w', encoding="utf-8") as fh:
        fh.write(pretty_jo)

# %% [markdown]
# <br />
# <br />
#
# <h4>Statistics for females</h4>

# %%
dd_legend_female = {
	'88.00–88.24' : '1e0204',
	'87.75–87.99' : '41050a',
	'87.50–87.74' : '60070f',
	'87.25–87.49' : '840a14',
	'87.00–87.24' : 'a30d19',
	'86.75–86.99' : 'bd0f25',
	'86.50–86.74' : 'd81132',
	'86.25–86.49' : 'ec183b',
	'86.00–86.24' : 'ef3b59',
	'85.75–85.99' : 'f1536e',
	'85.50–85.74' : 'f2657d',
	'85.25–85.49' : 'f3768b',
	'85.00–85.24' : 'f58698',
	'84.75–84.99' : 'f696a6',
	'84.50–84.74' : 'f7a5b2',
	'84.25–84.49' : 'f8b3be',
	'84.00–84.24' : 'f9bfc6',
	'83.75–83.99' : 'facdd3',
	'83.50–83.74' : 'fbd8db',
	'83.25–83.49' : 'fce2e4',
	'83.00–83.24' : 'fdebed',
	'82.75–82.99' : 'fef3f4',
	'82.50–82.74' : 'fef8f9',
	'82.25–82.49' : 'fefafa'
}

if CREATE_LEGEND_CODE:
    fn_create_legend_code(dd_legend_female)
# Out:
# {{Legend|#1e0204|88.00–88.24}}
# {{Legend|#41050a|87.75–87.99}}
# {{Legend|#60070f|87.50–87.74}}
# {{Legend|#840a14|87.25–87.49}}
# {{Legend|#a30d19|87.00–87.24}}
# {{Legend|#bd0f25|86.75–86.99}}
# {{Legend|#d81132|86.50–86.74}}
# {{Legend|#ec183b|86.25–86.49}}
# {{Legend|#ef3b59|86.00–86.24}}
# {{Legend|#f1536e|85.75–85.99}}
# {{Legend|#f2657d|85.50–85.74}}
# {{Legend|#f3768b|85.25–85.49}}
# {{Legend|#f58698|85.00–85.24}}
# {{Legend|#f696a6|84.75–84.99}}
# {{Legend|#f7a5b2|84.50–84.74}}
# {{Legend|#f8b3be|84.25–84.49}}
# {{Legend|#f9bfc6|84.00–84.24}}
# {{Legend|#facdd3|83.75–83.99}}
# {{Legend|#fbd8db|83.50–83.74}}
# {{Legend|#fce2e4|83.25–83.49}}
# {{Legend|#fdebed|83.00–83.24}}
# {{Legend|#fef3f4|82.75–82.99}}
# {{Legend|#fef8f9|82.50–82.74}}
# {{Legend|#fefafa|82.25–82.49}}

# %%
df_sel_year = filter_df(df, f"f_{SELECTED_YEAR}")
df_sel_year
# Out:
#            ——— f_2024 ———
# Range: 83.51 – 87.99   (Ceuta – Salamanca)
# Number of groups: 14
# Number of values: 52
#                         f_2024  group_label
#
# Salamanca                87.99  87.75–87.99
# Segovia                  87.84  87.75–87.99
# Madrid                   87.74  87.50–87.74
# ...                        ...          ...
# Santa_Cruz_de_Tenerife   84.94  84.75–84.99
# Almería                  84.90  84.75–84.99
# Ceuta                    83.51  83.50–83.74
#
# [52 rows x 2 columns]

# %%
ls_grouping = []
df_grouped = df_sel_year.groupby(['group_label']).apply(extract_indexes, dd_legend = dd_legend_female).loc[::-1]

# %%
if SELECTED_YEAR not in ['2020', '2021', '2022']:
    jo = create_map_code(ls_grouping, title=f'{SELECTED_YEAR}: ♀', legend_color='#333333')  # legend_color='#c20000'
    
    pretty_jo = json.dumps(jo, indent=2, ensure_ascii=False)
    
    with open(f"output/map_JSON -{SELECTED_YEAR}, female.txt", 'w', encoding="utf-8") as fh:
        fh.write(pretty_jo)
