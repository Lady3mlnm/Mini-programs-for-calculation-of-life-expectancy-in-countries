# %% [markdown]
# source of data: [The Japanese Mortality Database](https://www.ipss.go.jp/p-toukei/JMD/index-en.asp) > "Life expectancy at birth" tables<br>
# wiki > [List of Japanese prefectures by life expectancy](https://en.wikipedia.org/wiki/List_of_Japanese_prefectures_by_life_expectancy) <i>[(alternative)](https://en.wikipedia.org/wiki/User:Lady3mlnm/List_of_Japanese_prefectures_by_life_expectancy_(alternative))</i> / [Продолжительность жизни в префектурах Японии](https://ru.wikipedia.org/wiki/Продолжительность_жизни_в_префектурах_Японии)<br />
# [MapChart](https://www.mapchart.net/japan.html)<br />
# see also: [Nippon.com](https://www.nippon.com/en/search.html?s=life%20expectancy)

# %%
import pandas as pd
# import math
import re
from collections import namedtuple

import sys
sys.path.append("..")
import mal_moduls_private.mal_total as mal

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
pd.options.display.min_rows = 6
pd.options.display.max_rows = 50
YEARS_SEL = list(range(2010, 2024))
SORTED_BY = [2020, 2023]
SELECTED_YEAR = 2020
CREATE_LEGEND_CODE = True

# %%
CountryGroup = namedtuple('CountryGroup', ['group_label', 'color', 'countries'])

# %% [markdown]
# <br>

# %%
pattern_region_general = re.compile(r'(?<=^[\d.]{3}).*(?=(.ken|.to|.fu), Life expectancy)')  # what is in the most cases, like '47.Okinawa.ken'
pattern_region_1       = re.compile(r'(?<=^[\d.]{3}).*(?=, Life expectancy)')  # case of '01.Hokkaido' in the file Jp_01.csv
pattern_region_0       = re.compile(r'(?<=^).*(?=, Life expectancy)')  # case of 'Japan' in the file Jp_01.csv

def load_data_for_region(region_nmb):
    df = pd.read_csv(f"data-LE_at_birth/Jp_{region_nmb:02}.csv", sep='\t', skiprows=2, index_col='Year')

    with open(f"data-LE_at_birth/Jp_{region_nmb:02}.csv", 'r') as fh:
        title_line = fh.readline()
        if region_nmb >= 2:
            fragment_name_found = re.search(pattern_region_general, title_line)
        elif region_nmb == 1:
            fragment_name_found = re.search(pattern_region_1, title_line)
        elif region_nmb == 0:
            fragment_name_found = re.search(pattern_region_0, title_line)
        else:
            raise ValueError(f"Not expected region number: {region_nmb}")
        title = fragment_name_found.group() if fragment_name_found else 'region name is not found'

    df.name = title
        
    return df, title


df_t = df_m = df_f = pd.DataFrame()
ls_titles = []

for region_nmb in range(48):
    df_current, title_current = load_data_for_region(region_nmb)

    df_t = pd.concat([df_t, df_current.loc[YEARS_SEL, 'Total']], axis='columns')
    df_m = pd.concat([df_m, df_current.loc[YEARS_SEL, 'Male']], axis='columns')
    df_f = pd.concat([df_f, df_current.loc[YEARS_SEL, 'Female']], axis='columns')
    ls_titles.append(title_current)

df_t.columns = df_m.columns = df_f.columns = ls_titles

df_t = df_t.T
df_m = df_m.T
df_f = df_f.T

df_t.head(3)
# Out:
#            2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# Japan     82.95  82.71  83.21  83.43  83.68  83.92  84.10  84.22  84.32
# Hokkaido  82.70  82.83  82.98  83.19  83.42  83.63  83.69  83.99  83.98
# Aomori    81.33  81.55  81.50  81.91  82.05  82.41  82.65  82.74  82.81
#
#            2019   2020   2021   2022   2023
# Japan     84.46  84.71  84.58  84.10  84.14
# Hokkaido  84.07  84.32  83.98  83.57  83.62
# Aomori    82.60  83.09  82.96  82.69  82.22

# %%
# for region in df_t.index.to_list():
#     print(f"    '{region}'\t: {{'jp': ('', ''), 'en': ('', ''), 'ru': ('', '')}},")

# %% [markdown]
# <br>

# %%
# sort values
df_t = pd.concat([df_t.loc[['Japan']],
                  df_t.drop(index='Japan').sort_values(by=SORTED_BY, ascending=False)])

ls_indexes_sorted = df_t.index.to_list()
df_m = df_m.loc[ls_indexes_sorted]
df_f = df_f.loc[ls_indexes_sorted]

df_t.head(3)
# Out:
#         2010   2011   2012   2013   2014   2015   2016   2017   2018   2019  \
# Japan  82.95  82.71  83.21  83.43  83.68  83.92  84.10  84.22  84.32  84.46
# Shiga  83.66  83.84  83.98  84.20  84.52  84.63  84.99  84.96  85.15  85.35
# Kyoto  83.50  83.54  83.62  83.88  84.18  84.49  84.74  84.89  85.07  85.20
#
#         2020   2021   2022   2023
# Japan  84.71  84.58  84.10  84.14
# Shiga  85.71  85.60  85.09  85.19
# Kyoto  85.54  85.39  84.64  84.89

# %% [markdown]
# <br>

# %%
# just for interest, explore results: determine regions with max and min values, and also look at specific regions
mal.min_and_max_values(df_t, row_center=['Japan', 'Okinawa'], nmb=3, max_lng=9)
# Out:
# Number of records: 48
# <style type="text/css">
# #T_00d5e_row0_col0, #T_00d5e_row0_col1, #T_00d5e_row0_col2, #T_00d5e_row0_col3, #T_00d5e_row0_col4, #T_00d5e_row0_col5, #T_00d5e_row0_col6, #T_00d5e_row0_col7, #T_00d5e_row0_col8, #T_00d5e_row0_col9, #T_00d5e_row0_col10, #T_00d5e_row0_col11, #T_00d5e_row0_col12, #T_00d5e_row0_col13, #T_00d5e_row1_col0, #T_00d5e_row1_col1, #T_00d5e_row1_col2, #T_00d5e_row1_col3, #T_00d5e_row1_col4, #T_00d5e_row1_col5, #T_00d5e_row1_col6, #T_00d5e_row1_col7, #T_00d5e_row1_col8, #T_00d5e_row1_col9, #T_00d5e_row1_col10, #T_00d5e_row1_col11, #T_00d5e_row1_col12, #T_00d5e_row1_col13, #T_00d5e_row2_col0, #T_00d5e_row2_col1, #T_00d5e_row2_col2, #T_00d5e_row2_col3, #T_00d5e_row2_col4, #T_00d5e_row2_col5, #T_00d5e_row2_col6, #T_00d5e_row2_col7, #T_00d5e_row2_col8, #T_00d5e_row2_col9, #T_00d5e_row2_col10, #T_00d5e_row2_col11, #T_00d5e_row2_col12, #T_00d5e_row2_col13, #T_00d5e_row3_col0, #T_00d5e_row3_col1, #T_00d5e_row3_col2, #T_00d5e_row3_col3, #T_00d5e_row3_col4, #T_00d5e_row3_col5, #T_00d5e_row3_col6, #T_00d5e_row3_col7, #T_00d5e_row3_col8, #T_00d5e_row3_col9, #T_00d5e_row3_col10, #T_00d5e_row3_col11, #T_00d5e_row3_col12, #T_00d5e_row3_col13, #T_00d5e_row4_col0, #T_00d5e_row4_col1, #T_00d5e_row4_col2, #T_00d5e_row4_col3, #T_00d5e_row4_col4, #T_00d5e_row4_col5, #T_00d5e_row4_col6, #T_00d5e_row4_col7, #T_00d5e_row4_col8, #T_00d5e_row4_col9, #T_00d5e_row4_col10, #T_00d5e_row4_col11, #T_00d5e_row4_col12, #T_00d5e_row4_col13, #T_00d5e_row5_col0, #T_00d5e_row5_col1, #T_00d5e_row5_col2, #T_00d5e_row5_col3, #T_00d5e_row5_col4, #T_00d5e_row5_col5, #T_00d5e_row5_col6, #T_00d5e_row5_col7, #T_00d5e_row5_col8, #T_00d5e_row5_col9, #T_00d5e_row5_col10, #T_00d5e_row5_col11, #T_00d5e_row5_col12, #T_00d5e_row5_col13, #T_00d5e_row6_col0, #T_00d5e_row6_col1, #T_00d5e_row6_col2, #T_00d5e_row6_col3, #T_00d5e_row6_col4, #T_00d5e_row6_col5, #T_00d5e_row6_col6, #T_00d5e_row6_col7, #T_00d5e_row6_col8, #T_00d5e_row6_col9, #T_00d5e_row6_col10, #T_00d5e_row6_col11, #T_00d5e_row6_col12, #T_00d5e_row6_col13, #T_00d5e_row7_col0, #T_00d5e_row7_col1, #T_00d5e_row7_col2, #T_00d5e_row7_col3, #T_00d5e_row7_col4, #T_00d5e_row7_col5, #T_00d5e_row7_col6, #T_00d5e_row7_col7, #T_00d5e_row7_col8, #T_00d5e_row7_col9, #T_00d5e_row7_col10, #T_00d5e_row7_col11, #T_00d5e_row7_col12, #T_00d5e_row7_col13 {
#   text-align: left;
# }
# </style>
# <table id="T_00d5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00d5e_level0_col0" class="col_heading level0 col0" >2010</th>
#       <th id="T_00d5e_level0_col1" class="col_heading level0 col1" >2011</th>
#       <th id="T_00d5e_level0_col2" class="col_heading level0 col2" >2012</th>
#       <th id="T_00d5e_level0_col3" class="col_heading level0 col3" >2013</th>
#       <th id="T_00d5e_level0_col4" class="col_heading level0 col4" >2014</th>
#       <th id="T_00d5e_level0_col5" class="col_heading level0 col5" >2015</th>
#       <th id="T_00d5e_level0_col6" class="col_heading level0 col6" >2016</th>
#       <th id="T_00d5e_level0_col7" class="col_heading level0 col7" >2017</th>
#       <th id="T_00d5e_level0_col8" class="col_heading level0 col8" >2018</th>
#       <th id="T_00d5e_level0_col9" class="col_heading level0 col9" >2019</th>
#       <th id="T_00d5e_level0_col10" class="col_heading level0 col10" >2020</th>
#       <th id="T_00d5e_level0_col11" class="col_heading level0 col11" >2021</th>
#       <th id="T_00d5e_level0_col12" class="col_heading level0 col12" >2022</th>
#       <th id="T_00d5e_level0_col13" class="col_heading level0 col13" >2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00d5e_level0_row0" class="row_heading level0 row0" >max</th>
#       <td id="T_00d5e_row0_col0" class="data row0 col0" >84.04 -Nagano</td>
#       <td id="T_00d5e_row0_col1" class="data row0 col1" >83.86 -Nagano</td>
#       <td id="T_00d5e_row0_col2" class="data row0 col2" >84.03 -Nagano</td>
#       <td id="T_00d5e_row0_col3" class="data row0 col3" >84.47 -Nagano</td>
#       <td id="T_00d5e_row0_col4" class="data row0 col4" >84.52 -Shiga</td>
#       <td id="T_00d5e_row0_col5" class="data row0 col5" >84.93 -Nagano</td>
#       <td id="T_00d5e_row0_col6" class="data row0 col6" >84.99 -Shiga</td>
#       <td id="T_00d5e_row0_col7" class="data row0 col7" >85.02 -Nagano</td>
#       <td id="T_00d5e_row0_col8" class="data row0 col8" >85.28 -Nagano</td>
#       <td id="T_00d5e_row0_col9" class="data row0 col9" >85.35 -Shiga</td>
#       <td id="T_00d5e_row0_col10" class="data row0 col10" >85.71 -Shiga</td>
#       <td id="T_00d5e_row0_col11" class="data row0 col11" >85.67 -Nagano</td>
#       <td id="T_00d5e_row0_col12" class="data row0 col12" >85.16 -Nagano</td>
#       <td id="T_00d5e_row0_col13" class="data row0 col13" >85.28 -Nagano</td>
#     </tr>
#     <tr>
#       <th id="T_00d5e_level0_row1" class="row_heading level0 row1" >max_2</th>
#       <td id="T_00d5e_row1_col0" class="data row1 col0" >83.73 -Kumamoto</td>
#       <td id="T_00d5e_row1_col1" class="data row1 col1" >83.84 -Shiga</td>
#       <td id="T_00d5e_row1_col2" class="data row1 col2" >83.98 -Shiga</td>
#       <td id="T_00d5e_row1_col3" class="data row1 col3" >84.24 -Kumamoto</td>
#       <td id="T_00d5e_row1_col4" class="data row1 col4" >84.36 -Kumamoto</td>
#       <td id="T_00d5e_row1_col5" class="data row1 col5" >84.63 -Shiga</td>
#       <td id="T_00d5e_row1_col6" class="data row1 col6" >84.89 -Nagano</td>
#       <td id="T_00d5e_row1_col7" class="data row1 col7" >84.96 -Shiga</td>
#       <td id="T_00d5e_row1_col8" class="data row1 col8" >85.15 -Shiga</td>
#       <td id="T_00d5e_row1_col9" class="data row1 col9" >85.34 -Nagano</td>
#       <td id="T_00d5e_row1_col10" class="data row1 col10" >85.54 -Kyoto</td>
#       <td id="T_00d5e_row1_col11" class="data row1 col11" >85.6 -Shiga</td>
#       <td id="T_00d5e_row1_col12" class="data row1 col12" >85.09 -Shiga</td>
#       <td id="T_00d5e_row1_col13" class="data row1 col13" >85.19 -Shiga</td>
#     </tr>
#     <tr>
#       <th id="T_00d5e_level0_row2" class="row_heading level0 row2" >max_3</th>
#       <td id="T_00d5e_row2_col0" class="data row2 col0" >83.68 -Fukui</td>
#       <td id="T_00d5e_row2_col1" class="data row2 col1" >83.74 -Fukui</td>
#       <td id="T_00d5e_row2_col2" class="data row2 col2" >83.8 -Fukui</td>
#       <td id="T_00d5e_row2_col3" class="data row2 col3" >84.2 -Shiga</td>
#       <td id="T_00d5e_row2_col4" class="data row2 col4" >84.35 -Nagano</td>
#       <td id="T_00d5e_row2_col5" class="data row2 col5" >84.53 -Kumamoto</td>
#       <td id="T_00d5e_row2_col6" class="data row2 col6" >84.74 -Kyoto</td>
#       <td id="T_00d5e_row2_col7" class="data row2 col7" >84.89 -Kyoto</td>
#       <td id="T_00d5e_row2_col8" class="data row2 col8" >85.08 -Kumamoto</td>
#       <td id="T_00d5e_row2_col9" class="data row2 col9" >85.22 -Nara</td>
#       <td id="T_00d5e_row2_col10" class="data row2 col10" >85.51 -Nagano</td>
#       <td id="T_00d5e_row2_col11" class="data row2 col11" >85.39 -Kyoto</td>
#       <td id="T_00d5e_row2_col12" class="data row2 col12" >84.68 -Okayama</td>
#       <td id="T_00d5e_row2_col13" class="data row2 col13" >85.09 -Nara</td>
#     </tr>
#     <tr>
#       <th id="T_00d5e_level0_row3" class="row_heading level0 row3" >Japan</th>
#       <td id="T_00d5e_row3_col0" class="data row3 col0" > – 82.95 –</td>
#       <td id="T_00d5e_row3_col1" class="data row3 col1" > – 82.71 –</td>
#       <td id="T_00d5e_row3_col2" class="data row3 col2" > – 83.21 –</td>
#       <td id="T_00d5e_row3_col3" class="data row3 col3" > – 83.43 –</td>
#       <td id="T_00d5e_row3_col4" class="data row3 col4" > – 83.68 –</td>
#       <td id="T_00d5e_row3_col5" class="data row3 col5" > – 83.92 –</td>
#       <td id="T_00d5e_row3_col6" class="data row3 col6" > – 84.1 –</td>
#       <td id="T_00d5e_row3_col7" class="data row3 col7" > – 84.22 –</td>
#       <td id="T_00d5e_row3_col8" class="data row3 col8" > – 84.32 –</td>
#       <td id="T_00d5e_row3_col9" class="data row3 col9" > – 84.46 –</td>
#       <td id="T_00d5e_row3_col10" class="data row3 col10" > – 84.71 –</td>
#       <td id="T_00d5e_row3_col11" class="data row3 col11" > – 84.58 –</td

# %%
# for male
mal.min_and_max_values(df_m, row_center=['Japan', 'Okinawa'], nmb=3, max_lng=9)
# Out:
# Number of records: 48
# <style type="text/css">
# #T_a01c6_row0_col0, #T_a01c6_row0_col1, #T_a01c6_row0_col2, #T_a01c6_row0_col3, #T_a01c6_row0_col4, #T_a01c6_row0_col5, #T_a01c6_row0_col6, #T_a01c6_row0_col7, #T_a01c6_row0_col8, #T_a01c6_row0_col9, #T_a01c6_row0_col10, #T_a01c6_row0_col11, #T_a01c6_row0_col12, #T_a01c6_row0_col13, #T_a01c6_row1_col0, #T_a01c6_row1_col1, #T_a01c6_row1_col2, #T_a01c6_row1_col3, #T_a01c6_row1_col4, #T_a01c6_row1_col5, #T_a01c6_row1_col6, #T_a01c6_row1_col7, #T_a01c6_row1_col8, #T_a01c6_row1_col9, #T_a01c6_row1_col10, #T_a01c6_row1_col11, #T_a01c6_row1_col12, #T_a01c6_row1_col13, #T_a01c6_row2_col0, #T_a01c6_row2_col1, #T_a01c6_row2_col2, #T_a01c6_row2_col3, #T_a01c6_row2_col4, #T_a01c6_row2_col5, #T_a01c6_row2_col6, #T_a01c6_row2_col7, #T_a01c6_row2_col8, #T_a01c6_row2_col9, #T_a01c6_row2_col10, #T_a01c6_row2_col11, #T_a01c6_row2_col12, #T_a01c6_row2_col13, #T_a01c6_row3_col0, #T_a01c6_row3_col1, #T_a01c6_row3_col2, #T_a01c6_row3_col3, #T_a01c6_row3_col4, #T_a01c6_row3_col5, #T_a01c6_row3_col6, #T_a01c6_row3_col7, #T_a01c6_row3_col8, #T_a01c6_row3_col9, #T_a01c6_row3_col10, #T_a01c6_row3_col11, #T_a01c6_row3_col12, #T_a01c6_row3_col13, #T_a01c6_row4_col0, #T_a01c6_row4_col1, #T_a01c6_row4_col2, #T_a01c6_row4_col3, #T_a01c6_row4_col4, #T_a01c6_row4_col5, #T_a01c6_row4_col6, #T_a01c6_row4_col7, #T_a01c6_row4_col8, #T_a01c6_row4_col9, #T_a01c6_row4_col10, #T_a01c6_row4_col11, #T_a01c6_row4_col12, #T_a01c6_row4_col13, #T_a01c6_row5_col0, #T_a01c6_row5_col1, #T_a01c6_row5_col2, #T_a01c6_row5_col3, #T_a01c6_row5_col4, #T_a01c6_row5_col5, #T_a01c6_row5_col6, #T_a01c6_row5_col7, #T_a01c6_row5_col8, #T_a01c6_row5_col9, #T_a01c6_row5_col10, #T_a01c6_row5_col11, #T_a01c6_row5_col12, #T_a01c6_row5_col13, #T_a01c6_row6_col0, #T_a01c6_row6_col1, #T_a01c6_row6_col2, #T_a01c6_row6_col3, #T_a01c6_row6_col4, #T_a01c6_row6_col5, #T_a01c6_row6_col6, #T_a01c6_row6_col7, #T_a01c6_row6_col8, #T_a01c6_row6_col9, #T_a01c6_row6_col10, #T_a01c6_row6_col11, #T_a01c6_row6_col12, #T_a01c6_row6_col13, #T_a01c6_row7_col0, #T_a01c6_row7_col1, #T_a01c6_row7_col2, #T_a01c6_row7_col3, #T_a01c6_row7_col4, #T_a01c6_row7_col5, #T_a01c6_row7_col6, #T_a01c6_row7_col7, #T_a01c6_row7_col8, #T_a01c6_row7_col9, #T_a01c6_row7_col10, #T_a01c6_row7_col11, #T_a01c6_row7_col12, #T_a01c6_row7_col13 {
#   text-align: left;
# }
# </style>
# <table id="T_a01c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a01c6_level0_col0" class="col_heading level0 col0" >2010</th>
#       <th id="T_a01c6_level0_col1" class="col_heading level0 col1" >2011</th>
#       <th id="T_a01c6_level0_col2" class="col_heading level0 col2" >2012</th>
#       <th id="T_a01c6_level0_col3" class="col_heading level0 col3" >2013</th>
#       <th id="T_a01c6_level0_col4" class="col_heading level0 col4" >2014</th>
#       <th id="T_a01c6_level0_col5" class="col_heading level0 col5" >2015</th>
#       <th id="T_a01c6_level0_col6" class="col_heading level0 col6" >2016</th>
#       <th id="T_a01c6_level0_col7" class="col_heading level0 col7" >2017</th>
#       <th id="T_a01c6_level0_col8" class="col_heading level0 col8" >2018</th>
#       <th id="T_a01c6_level0_col9" class="col_heading level0 col9" >2019</th>
#       <th id="T_a01c6_level0_col10" class="col_heading level0 col10" >2020</th>
#       <th id="T_a01c6_level0_col11" class="col_heading level0 col11" >2021</th>
#       <th id="T_a01c6_level0_col12" class="col_heading level0 col12" >2022</th>
#       <th id="T_a01c6_level0_col13" class="col_heading level0 col13" >2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a01c6_level0_row0" class="row_heading level0 row0" >max</th>
#       <td id="T_a01c6_row0_col0" class="data row0 col0" >80.82 -Nagano</td>
#       <td id="T_a01c6_row0_col1" class="data row0 col1" >80.86 -Nagano</td>
#       <td id="T_a01c6_row0_col2" class="data row0 col2" >81.18 -Shiga</td>
#       <td id="T_a01c6_row0_col3" class="data row0 col3" >81.37 -Nagano</td>
#       <td id="T_a01c6_row0_col4" class="data row0 col4" >81.53 -Shiga</td>
#       <td id="T_a01c6_row0_col5" class="data row0 col5" >81.85 -Nagano</td>
#       <td id="T_a01c6_row0_col6" class="data row0 col6" >81.97 -Nagano</td>
#       <td id="T_a01c6_row0_col7" class="data row0 col7" >82.11 -Nagano</td>
#       <td id="T_a01c6_row0_col8" class="data row0 col8" >82.44 -Nagano</td>
#       <td id="T_a01c6_row0_col9" class="data row0 col9" >82.55 -Nagano</td>
#       <td id="T_a01c6_row0_col10" class="data row0 col10" >82.88 -Shiga</td>
#       <td id="T_a01c6_row0_col11" class="data row0 col11" >82.94 -Nagano</td>
#       <td id="T_a01c6_row0_col12" class="data row0 col12" >82.4 -Nagano</td>
#       <td id="T_a01c6_row0_col13" class="data row0 col13" >82.58 -Nagano</td>
#     </tr>
#     <tr>
#       <th id="T_a01c6_level0_row1" class="row_heading level0 row1" >max_2</th>
#       <td id="T_a01c6_row1_col0" class="data row1 col0" >80.51 -Shiga</td>
#       <td id="T_a01c6_row1_col1" class="data row1 col1" >80.66 -Shiga</td>
#       <td id="T_a01c6_row1_col2" class="data row1 col2" >80.97 -Nagano</td>
#       <td id="T_a01c6_row1_col3" class="data row1 col3" >81.0 -Shiga</td>
#       <td id="T_a01c6_row1_col4" class="data row1 col4" >81.31 -Nagano</td>
#       <td id="T_a01c6_row1_col5" class="data row1 col5" >81.73 -Shiga</td>
#       <td id="T_a01c6_row1_col6" class="data row1 col6" >81.93 -Shiga</td>
#       <td id="T_a01c6_row1_col7" class="data row1 col7" >81.92 -Shiga</td>
#       <td id="T_a01c6_row1_col8" class="data row1 col8" >82.33 -Shiga</td>
#       <td id="T_a01c6_row1_col9" class="data row1 col9" >82.54 -Shiga</td>
#       <td id="T_a01c6_row1_col10" class="data row1 col10" >82.54 -Nagano</td>
#       <td id="T_a01c6_row1_col11" class="data row1 col11" >82.75 -Shiga</td>
#       <td id="T_a01c6_row1_col12" class="data row1 col12" >82.18 -Shiga</td>
#       <td id="T_a01c6_row1_col13" class="data row1 col13" >82.38 -Nara</td>
#     </tr>
#     <tr>
#       <th id="T_a01c6_level0_row2" class="row_heading level0 row2" >max_3</th>
#       <td id="T_a01c6_row2_col0" class="data row2 col0" >80.4 -Fukui</td>
#       <td id="T_a01c6_row2_col1" class="data row2 col1" >80.54 -Nara</td>
#       <td id="T_a01c6_row2_col2" class="data row2 col2" >80.6 -Fukui</td>
#       <td id="T_a01c6_row2_col3" class="data row2 col3" >80.92 -Kumamoto</td>
#       <td id="T_a01c6_row2_col4" class="data row2 col4" >81.02 -Kyoto</td>
#       <td id="T_a01c6_row2_col5" class="data row2 col5" >81.44 -Nara</td>
#       <td id="T_a01c6_row2_col6" class="data row2 col6" >81.71 -Nara</td>
#       <td id="T_a01c6_row2_col7" class="data row2 col7" >81.86 -Kyoto</td>
#       <td id="T_a01c6_row2_col8" class="data row2 col8" >82.03 -Kyoto</td>
#       <td id="T_a01c6_row2_col9" class="data row2 col9" >82.26 -Nara</td>
#       <td id="T_a01c6_row2_col10" class="data row2 col10" >82.45 -Nara</td>
#       <td id="T_a01c6_row2_col11" class="data row2 col11" >82.45 -Nara</td>
#       <td id="T_a01c6_row2_col12" class="data row2 col12" >81.74 -Nara</td>
#       <td id="T_a01c6_row2_col13" class="data row2 col13" >82.31 -Shiga</td>
#     </tr>
#     <tr>
#       <th id="T_a01c6_level0_row3" class="row_heading level0 row3" >Japan</th>
#       <td id="T_a01c6_row3_col0" class="data row3 col0" > – 79.51 –</td>
#       <td id="T_a01c6_row3_col1" class="data row3 col1" > – 79.41 –</td>
#       <td id="T_a01c6_row3_col2" class="data row3 col2" > – 79.91 –</td>
#       <td id="T_a01c6_row3_col3" class="data row3 col3" > – 80.17 –</td>
#       <td id="T_a01c6_row3_col4" class="data row3 col4" > – 80.46 –</td>
#       <td id="T_a01c6_row3_col5" class="data row3 col5" > – 80.72 –</td>
#       <td id="T_a01c6_row3_col6" class="data row3 col6" > – 80.94 –</td>
#       <td id="T_a01c6_row3_col7" class="data row3 col7" > – 81.06 –</td>
#       <td id="T_a01c6_row3_col8" class="data row3 col8" > – 81.22 –</td>
#       <td id="T_a01c6_row3_col9" class="data row3 col9" > – 81.37 –</td>
#       <td id="T_a01c6_row3_col10" class="data row3 col10" > – 81.58 –</td>
#       <td id="T_a01c6_row3_col11" class="data row3 col11" > – 81.49 –</td>
#       <td id="T_a0

# %%
# for female
mal.min_and_max_values(df_f, row_center=['Japan', 'Okinawa'], nmb=3, max_lng=9)
# Out:
# Number of records: 48
# <style type="text/css">
# #T_e2e4a_row0_col0, #T_e2e4a_row0_col1, #T_e2e4a_row0_col2, #T_e2e4a_row0_col3, #T_e2e4a_row0_col4, #T_e2e4a_row0_col5, #T_e2e4a_row0_col6, #T_e2e4a_row0_col7, #T_e2e4a_row0_col8, #T_e2e4a_row0_col9, #T_e2e4a_row0_col10, #T_e2e4a_row0_col11, #T_e2e4a_row0_col12, #T_e2e4a_row0_col13, #T_e2e4a_row1_col0, #T_e2e4a_row1_col1, #T_e2e4a_row1_col2, #T_e2e4a_row1_col3, #T_e2e4a_row1_col4, #T_e2e4a_row1_col5, #T_e2e4a_row1_col6, #T_e2e4a_row1_col7, #T_e2e4a_row1_col8, #T_e2e4a_row1_col9, #T_e2e4a_row1_col10, #T_e2e4a_row1_col11, #T_e2e4a_row1_col12, #T_e2e4a_row1_col13, #T_e2e4a_row2_col0, #T_e2e4a_row2_col1, #T_e2e4a_row2_col2, #T_e2e4a_row2_col3, #T_e2e4a_row2_col4, #T_e2e4a_row2_col5, #T_e2e4a_row2_col6, #T_e2e4a_row2_col7, #T_e2e4a_row2_col8, #T_e2e4a_row2_col9, #T_e2e4a_row2_col10, #T_e2e4a_row2_col11, #T_e2e4a_row2_col12, #T_e2e4a_row2_col13, #T_e2e4a_row3_col0, #T_e2e4a_row3_col1, #T_e2e4a_row3_col2, #T_e2e4a_row3_col3, #T_e2e4a_row3_col4, #T_e2e4a_row3_col5, #T_e2e4a_row3_col6, #T_e2e4a_row3_col7, #T_e2e4a_row3_col8, #T_e2e4a_row3_col9, #T_e2e4a_row3_col10, #T_e2e4a_row3_col11, #T_e2e4a_row3_col12, #T_e2e4a_row3_col13, #T_e2e4a_row4_col0, #T_e2e4a_row4_col1, #T_e2e4a_row4_col2, #T_e2e4a_row4_col3, #T_e2e4a_row4_col4, #T_e2e4a_row4_col5, #T_e2e4a_row4_col6, #T_e2e4a_row4_col7, #T_e2e4a_row4_col8, #T_e2e4a_row4_col9, #T_e2e4a_row4_col10, #T_e2e4a_row4_col11, #T_e2e4a_row4_col12, #T_e2e4a_row4_col13, #T_e2e4a_row5_col0, #T_e2e4a_row5_col1, #T_e2e4a_row5_col2, #T_e2e4a_row5_col3, #T_e2e4a_row5_col4, #T_e2e4a_row5_col5, #T_e2e4a_row5_col6, #T_e2e4a_row5_col7, #T_e2e4a_row5_col8, #T_e2e4a_row5_col9, #T_e2e4a_row5_col10, #T_e2e4a_row5_col11, #T_e2e4a_row5_col12, #T_e2e4a_row5_col13, #T_e2e4a_row6_col0, #T_e2e4a_row6_col1, #T_e2e4a_row6_col2, #T_e2e4a_row6_col3, #T_e2e4a_row6_col4, #T_e2e4a_row6_col5, #T_e2e4a_row6_col6, #T_e2e4a_row6_col7, #T_e2e4a_row6_col8, #T_e2e4a_row6_col9, #T_e2e4a_row6_col10, #T_e2e4a_row6_col11, #T_e2e4a_row6_col12, #T_e2e4a_row6_col13, #T_e2e4a_row7_col0, #T_e2e4a_row7_col1, #T_e2e4a_row7_col2, #T_e2e4a_row7_col3, #T_e2e4a_row7_col4, #T_e2e4a_row7_col5, #T_e2e4a_row7_col6, #T_e2e4a_row7_col7, #T_e2e4a_row7_col8, #T_e2e4a_row7_col9, #T_e2e4a_row7_col10, #T_e2e4a_row7_col11, #T_e2e4a_row7_col12, #T_e2e4a_row7_col13 {
#   text-align: left;
# }
# </style>
# <table id="T_e2e4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2e4a_level0_col0" class="col_heading level0 col0" >2010</th>
#       <th id="T_e2e4a_level0_col1" class="col_heading level0 col1" >2011</th>
#       <th id="T_e2e4a_level0_col2" class="col_heading level0 col2" >2012</th>
#       <th id="T_e2e4a_level0_col3" class="col_heading level0 col3" >2013</th>
#       <th id="T_e2e4a_level0_col4" class="col_heading level0 col4" >2014</th>
#       <th id="T_e2e4a_level0_col5" class="col_heading level0 col5" >2015</th>
#       <th id="T_e2e4a_level0_col6" class="col_heading level0 col6" >2016</th>
#       <th id="T_e2e4a_level0_col7" class="col_heading level0 col7" >2017</th>
#       <th id="T_e2e4a_level0_col8" class="col_heading level0 col8" >2018</th>
#       <th id="T_e2e4a_level0_col9" class="col_heading level0 col9" >2019</th>
#       <th id="T_e2e4a_level0_col10" class="col_heading level0 col10" >2020</th>
#       <th id="T_e2e4a_level0_col11" class="col_heading level0 col11" >2021</th>
#       <th id="T_e2e4a_level0_col12" class="col_heading level0 col12" >2022</th>
#       <th id="T_e2e4a_level0_col13" class="col_heading level0 col13" >2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2e4a_level0_row0" class="row_heading level0 row0" >max</th>
#       <td id="T_e2e4a_row0_col0" class="data row0 col0" >87.12 -Nagano</td>
#       <td id="T_e2e4a_row0_col1" class="data row0 col1" >87.06 -Shimane</td>
#       <td id="T_e2e4a_row0_col2" class="data row0 col2" >87.38 -Okinawa</td>
#       <td id="T_e2e4a_row0_col3" class="data row0 col3" >87.45 -Nagano</td>
#       <td id="T_e2e4a_row0_col4" class="data row0 col4" >87.58 -Shimane</td>
#       <td id="T_e2e4a_row0_col5" class="data row0 col5" >87.91 -Nagano</td>
#       <td id="T_e2e4a_row0_col6" class="data row0 col6" >87.91 -Shiga</td>
#       <td id="T_e2e4a_row0_col7" class="data row0 col7" >87.93 -Okayama</td>
#       <td id="T_e2e4a_row0_col8" class="data row0 col8" >88.14 -Shimane</td>
#       <td id="T_e2e4a_row0_col9" class="data row0 col9" >88.21 -Shimane</td>
#       <td id="T_e2e4a_row0_col10" class="data row0 col10" >88.68 -Tottori</td>
#       <td id="T_e2e4a_row0_col11" class="data row0 col11" >88.36 -Shiga</td>
#       <td id="T_e2e4a_row0_col12" class="data row0 col12" >87.97 -Shiga</td>
#       <td id="T_e2e4a_row0_col13" class="data row0 col13" >88.14 -Shimane</td>
#     </tr>
#     <tr>
#       <th id="T_e2e4a_level0_row1" class="row_heading level0 row1" >max_2</th>
#       <td id="T_e2e4a_row1_col0" class="data row1 col0" >86.99 -Okinawa</td>
#       <td id="T_e2e4a_row1_col1" class="data row1 col1" >87.04 -Fukui</td>
#       <td id="T_e2e4a_row1_col2" class="data row1 col2" >87.06 -Shimane</td>
#       <td id="T_e2e4a_row1_col3" class="data row1 col3" >87.26 -Shiga</td>
#       <td id="T_e2e4a_row1_col4" class="data row1 col4" >87.5 -Fukui</td>
#       <td id="T_e2e4a_row1_col5" class="data row1 col5" >87.59 -Shimane</td>
#       <td id="T_e2e4a_row1_col6" class="data row1 col6" >87.8 -Okayama</td>
#       <td id="T_e2e4a_row1_col7" class="data row1 col7" >87.9 -Shiga</td>
#       <td id="T_e2e4a_row1_col8" class="data row1 col8" >88.12 -Fukui</td>
#       <td id="T_e2e4a_row1_col9" class="data row1 col9" >88.12 -Okayama</td>
#       <td id="T_e2e4a_row1_col10" class="data row1 col10" >88.53 -Okayama</td>
#       <td id="T_e2e4a_row1_col11" class="data row1 col11" >88.33 -Shimane</td>
#       <td id="T_e2e4a_row1_col12" class="data row1 col12" >87.96 -Shimane</td>
#       <td id="T_e2e4a_row1_col13" class="data row1 col13" >88.06 -Shiga</td>
#     </tr>
#     <tr>
#       <th id="T_e2e4a_level0_row2" class="row_heading level0 row2" >max_3</th>
#       <td id="T_e2e4a_row2_col0" class="data row2 col0" >86.98 -Shimane</td>
#       <td id="T_e2e4a_row2_col1" class="data row2 col1" >86.93 -Okayama</td>
#       <td id="T_e2e4a_row2_col2" class="data row2 col2" >86.99 -Niigata</td>
#       <td id="T_e2e4a_row2_col3" class="data row2 col3" >87.25 -Okinawa</td>
#       <td id="T_e2e4a_row2_col4" class="data row2 col4" >87.48 -Okayama</td>
#       <td id="T_e2e4a_row2_col5" class="data row2 col5" >87.56 -Okayama</td>
#       <td id="T_e2e4a_row2_col6" class="data row2 col6" >87.69 -Nagano</td>
#       <td id="T_e2e4a_row2_col7" class="data row2 col7" >87.84 -Okinawa</td>
#       <td id="T_e2e4a_row2_col8" class="data row2 col8" >88.04 -Tottori</td>
#       <td id="T_e2e4a_row2_col9" class="data row2 col9" >88.03 -Shiga</td>
#       <td id="T_e2e4a_row2_col10" class="data row2 col10" >88.51 -Kumamoto</td>
#       <td id="T_e2e4a_row2_col11" class="data row2 col11" >88.31 -Nagano</td>
#       <td id="T_e2e4a_row2_col12" class="data row2 col12" >87.91 -Nagano</td>
#       <td id="T_e2e4a_row2_col13" class="data row2 col13" >87.96 -Nagano</td>
#     </tr>
#     <tr>
#       <th id="T_e2e4a_level0_row3" class="row_heading level0 row3" >Japan</th>
#       <td id="T_e2e4a_row3_col0" class="data row3 col0" > – 86.24 –</td>
#       <td id="T_e2e4a_row3_col1" class="data row3 col1" > – 85.86 –</td>
#       <td id="T_e2e4a_row3_col2" class="data row3 col2" > – 86.36 –</td>
#       <td id="T_e2e4a_row3_col3" class="data row3 col3" > – 86.56 –</td>
#       <td id="T_e2e4a_row3_col4" class="data row3 col4" > – 86.77 –</td>
#       <td id="T_e2e4a_row3_col5" class="data row3 col5" > – 86.97 –</td>
#       <td id="T_e2e4a_row3_col6" class="data row3 col6" > – 87.12 –</td>
#       <td id="T_e2e4a_row3_col7" class="data row3 col7" > – 87.26 –</td>
#       <td id="T_e2e4a_row3_col8" class="data row3 col8" > – 87.31 –</td>
#       <td id="T_e2e4a_row3_col9" class="data row3 col9" > – 87.44 –</td>
#       <td id="T_e2e4a_row3_col10" class="data row3 col10" > – 87.73 –</td>
#       <td id="T_e2e4a_row3_col11" class="da

# %% [markdown]
# <br />
# <br />

# %%
# ls_1 = sorted(df_t.drop(index='Japan').index.to_list())
# print(len(ls_1))
# ls_1[:5]

# %%
# ls_2 = ["Aichi", "Akita", "Aomori", "Chiba", "Ehime", "Fukui", "Fukuoka", "Fukushima", "Gifu", "Gunma", "Hiroshima",
#         "Hokkaido", "Hyogo", "Ibaraki", "Ishikawa", "Iwate", "Kagawa", "Kagoshima", "Kanagawa", "Kochi", "Kumamoto",
#         "Kyoto", "Mie", "Miyagi", "Miyazaki", "Nagano", "Nagasaki", "Nara", "Niigata", "Oita", "Okayama", "Okinawa",
#         "Osaka", "Saga", "Saitama", "Shiga", "Shimane", "Shizuoka", "Tochigi", "Tokushima", "Tokyo", "Tottori",
#         "Toyama", "Wakayama", "Yamagata", "Yamaguchi", "Yamanashi"]
# print(len(ls_2))

# %%
# mal.compare_lists(ls_1, ls_2)

# %% [markdown]
# <br />
# <br />

# %%
# renaming of provinces according to requirement of the online-service 'MapChart'
df_t.rename(index={
    'Gumma' : 'Gunma'
}, inplace=True)

df_m.rename(index={
    'Gumma' : 'Gunma'
}, inplace=True)

df_f.rename(index={
    'Gumma' : 'Gunma'
}, inplace=True)

# %% [markdown]
# <br />
# <br />
#
# <h4>Overall statistics</h4>

# %%
dd_legend_main = {
    '85.50–85.74' : '007800',
    '85.25–85.49' : '008800',
    '85.00–85.24' : '009800',
    '84.75–84.99' : '00a700',
    '84.50–84.74' : '00b800',
    '84.25–84.49' : '00cb00',
    '84.00–84.24' : '00e000',
    '83.75–83.99' : '00f000',
    '83.50–83.74' : '00ff00',
    '83.25–83.49' : '88ff00',
    '83.00–83.24' : 'b8ff00',
    '82.75–82.99' : 'deff00',
    '82.50–82.74' : 'ffff00',
    '82.25–82.49' : 'ffef00',
    '82.00–82.24' : 'ffe000',
    '81.75–81.99' : 'ffce00',
    '81.50–81.74' : 'ffbc00',
    '81.25–81.49' : 'ffac00',
    '81.00–81.24' : 'ff9c00',
    '80.75–80.99' : 'ff8700',
    '80.50–80.74' : 'ff7400',
    '80.25–80.49' : 'ff5200',
    '80.00–80.24' : 'ff0000',
    '79.75–79.99' : 'e10000',
	'79.50–79.74' : 'c70000',
	'79.25–79.49' : 'af0000',
	'79.00–79.24' : '9e0000',
	'78.75–78.99' : '8b0000',
	'78.50–78.74' : '790000',
	'78.25–78.49' : '670000',
	'78.00–78.24' : '580000'
}

def fn_create_legend_code(dd_legend):
    for k, v in dd_legend.items():
        print(f"{{{{Legend|#{v}|{k}}}}}")  

if CREATE_LEGEND_CODE:
    fn_create_legend_code(dd_legend_main)
# Out:
# {{Legend|#007800|85.50–85.74}}
# {{Legend|#008800|85.25–85.49}}
# {{Legend|#009800|85.00–85.24}}
# {{Legend|#00a700|84.75–84.99}}
# {{Legend|#00b800|84.50–84.74}}
# {{Legend|#00cb00|84.25–84.49}}
# {{Legend|#00e000|84.00–84.24}}
# {{Legend|#00f000|83.75–83.99}}
# {{Legend|#00ff00|83.50–83.74}}
# {{Legend|#88ff00|83.25–83.49}}
# {{Legend|#b8ff00|83.00–83.24}}
# {{Legend|#deff00|82.75–82.99}}
# {{Legend|#ffff00|82.50–82.74}}
# {{Legend|#ffef00|82.25–82.49}}
# {{Legend|#ffe000|82.00–82.24}}
# {{Legend|#ffce00|81.75–81.99}}
# {{Legend|#ffbc00|81.50–81.74}}
# {{Legend|#ffac00|81.25–81.49}}
# {{Legend|#ff9c00|81.00–81.24}}
# {{Legend|#ff8700|80.75–80.99}}
# {{Legend|#ff7400|80.50–80.74}}
# {{Legend|#ff5200|80.25–80.49}}
# {{Legend|#ff0000|80.00–80.24}}
# {{Legend|#e10000|79.75–79.99}}
# {{Legend|#c70000|79.50–79.74}}
# {{Legend|#af0000|79.25–79.49}}
# {{Legend|#9e0000|79.00–79.24}}
# {{Legend|#8b0000|78.75–78.99}}
# {{Legend|#790000|78.50–78.74}}
# {{Legend|#670000|78.25–78.49}}
# {{Legend|#580000|78.00–78.24}}

# %%
def filter_df(df, selected_year=SELECTED_YEAR):
    filtered_df = df.loc[:, [selected_year]]   \
                    .sort_values(by=selected_year, ascending=False) \
                    .dropna()

    filtered_df['group_label'] = filtered_df[selected_year].map(lambda x: f"{x * 8 // 2 / 4:.2f}–{x * 8 // 2 / 4 + 0.24:.2f}")
    # filtered_df['group_label'] = filtered_df[selected_year].map(lambda x: f"{x * 10 // 2 / 5:.1f}–{x * 10 // 2 / 5 + 0.19:.2f}")
    
    filtered_df['group_label'] = filtered_df['group_label']
    
    min_value = filtered_df[selected_year].min()
    max_value = filtered_df[selected_year].max()
    
    print(f"           ——— {selected_year} ———")
    print(f"Range: {min_value:.2f} – {max_value:.2f}   " +
          f"({filtered_df[selected_year].idxmin()} – {filtered_df[selected_year].idxmax()})")
    print(f"Number of groups: {filtered_df['group_label'].nunique()}")
    print(f"Number of values: {len(filtered_df)}")

    return filtered_df

df_sel_year = filter_df(df_t, SELECTED_YEAR)
df_sel_year
# Out:
#            ——— 2020 ———
# Range: 83.09 – 85.71   (Aomori – Shiga)
# Number of groups: 9
# Number of values: 48
#             2020  group_label
# Shiga      85.71  85.50–85.74
# Kyoto      85.54  85.50–85.74
# Nagano     85.51  85.50–85.74
# Nara       85.45  85.25–85.49
# Okayama    85.39  85.25–85.49
# Kumamoto   85.37  85.25–85.49
# Hiroshima  85.37  85.25–85.49
# Tottori    85.31  85.25–85.49
# Ishikawa   85.25  85.25–85.49
# Toyama     85.22  85.00–85.24
# Oita       85.22  85.00–85.24
# Kanagawa   85.04  85.00–85.24
# Gifu       85.03  85.00–85.24
# Hyogo      85.02  85.00–85.24
# Yamanashi  85.01  85.00–85.24
# Shimane    84.98  84.75–84.99
# Tokyo      84.97  84.75–84.99
# Fukui      84.92  84.75–84.99
# Fukuoka    84.90  84.75–84.99
# Saga       84.89  84.75–84.99
# Miyagi     84.86  84.75–84.99
# Niigata    84.72  84.50–84.74
# Japan      84.71  84.50–84.74
# Aichi      84.69  84.50–84.74
# Mie        84.67  84.50–84.74
# Yamaguchi  84.63  84.50–84.74
# Kochi      84.61  84.50–84.74
# Kagawa     84.60  84.50–84.74
# Ehime      84.56  84.50–84.74
# Shizuoka   84.55  84.50–84.74
# Chiba      84.55  84.50–84.74
# Okinawa    84.52  84.50–84.74
# Wakayama   84.49  84.25–84.49
# Yamagata   84.42  84.25–84.49
# Tokushima  84.42  84.25–84.49
# Miyazaki   84.39  84.25–84.49
# Saitama    84.39  84.25–84.49
# Kagoshima  84.38  84.25–84.49
# Nagasaki   84.33  84.25–84.49
# Hokkaido   84.32  84.25–84.49
# Gunma      84.30  84.25–84.49
# Osaka      84.23  84.00–84.24
# Tochigi    84.15  84.00–84.24
# Iwate      84.12  84.00–84.24
# Akita      84.03  84.00–84.24
# Fukushima  83.96  83.75–83.99
# Ibaraki    83.93  83.75–83.99
# Aomori     83.09  83.00–83.24

# %%
def extract_indexes(subdf, dd_legend):
    group_label = subdf['group_label'].iloc[0]
    countries = subdf.index.to_list()
    color = (dd_legend[group_label])
    
    ls_grouping.append(CountryGroup(group_label=group_label, countries=countries, color=color))

    return pd.Series([color, countries], index=['color', 'regions'])


ls_grouping = []
df_grouped = df_sel_year.groupby(['group_label']).apply(extract_indexes, dd_legend = dd_legend_main).loc[::-1]

df_grouped
# Out:
#               color                                            regions
# group_label
# 85.50–85.74  007800                             [Shiga, Kyoto, Nagano]
# 85.25–85.49  008800  [Nara, Okayama, Kumamoto, Hiroshima, Tottori, ...
# 85.00–85.24  009800   [Toyama, Oita, Kanagawa, Gifu, Hyogo, Yamanashi]
# 84.75–84.99  00a700     [Shimane, Tokyo, Fukui, Fukuoka, Saga, Miyagi]
# 84.50–84.74  00b800  [Niigata, Japan, Aichi, Mie, Yamaguchi, Kochi,...
# 84.25–84.49  00cb00  [Wakayama, Yamagata, Tokushima, Miyazaki, Sait...
# 84.00–84.24  00e000                     [Osaka, Tochigi, Iwate, Akita]
# 83.75–83.99  00f000                               [Fukushima, Ibaraki]
# 83.00–83.24  b8ff00                                           [Aomori]

# %%
def create_map_code(ls_grouping, title='', legend_color='#000'):  # (ls_grouping, title='', legend_color='#000'):
    false, true = False, True

    jo = {
        "groups": { },
        "title": title,
        "hidden": [],
        "background": "#ffffff",
        "borders": "#000",
        "legendFont": "Century Gothic",
        "legendFontColor": "#000",
        "legendBorderColor": "#00000000",
        "legendBgColor": "#00000000",
        "legendWidth": 150,
        "legendBoxShape": "square",
        "areBordersShown": true,
        "defaultColor": "#d1dbdd",
        "labelsColor": "#6a0707",
        "labelsFont": "Arial",
        "strokeWidth": "medium",
        "areLabelsShown": true,
        "uncoloredScriptColor": "#ffff33",
        "zoomLevel": "1.00",
        "zoomX": "0.00",
        "zoomY": "0.00",
        "v6": true,
        "page": "japan",
        "legendPosition": "custom",
        "legendX": 84,
        "legendY": 36,
        "legendSize": "medium",
        "legendTranslateX": "0.00",
        "legendStatus": "show",
        "scalingPatterns": true,
        "legendRowsSameColor": true,
        "legendColumnCount": 1
    }

    for group_label, color, regions in ls_grouping[::-1]:
        jo["groups"][f"#{color}"] = {"label": group_label.replace('.00', '.0').replace('.25', '¼').replace('.50', '.5').replace('.75', '¾').replace('–', ' - '),
                                     "paths": [region.replace(' ', '_') for region in regions]}       

    return jo


jo = create_map_code(ls_grouping, title=f'{SELECTED_YEAR}', legend_color='#333333')

pretty_jo = json.dumps(jo, indent=2, ensure_ascii=False)

with open(f"output/map_JSON -{SELECTED_YEAR}.txt", 'w', encoding="utf-8") as fh:
    fh.write(pretty_jo)

# %% [markdown]
# <br />
# <br />
#
# <h4>Statistics for males</h4>

# %%
dd_legend_male = {
    '83.00–83.24' : '020f19',
	'82.75–82.99' : '042136',
	'82.50–82.74' : '062f4c',
	'82.25–82.49' : '073a5e',
	'82.00–82.24' : '08436e',
	'81.75–81.99' : '0a4e7f',
	'81.50–81.74' : '0b578d',
	'81.25–81.49' : '0c609c',
	'81.00–81.24' : '0d68a9',
	'80.75–80.99' : '0e71b7',
	'80.50–80.74' : '107ac6',
	'80.25–80.49' : '1182d4',
	'80.00–80.24' : '128be1',
	'79.75–79.99' : '1c95ec',
	'79.50–79.74' : '2e9eee',
	'79.25–79.49' : '40a6ef',
	'79.00–79.24' : '51aef0',
	'78.75–78.99' : '61b5f2',
	'78.50–78.74' : '6ebcf3',
	'78.25–78.49' : '80c4f4',
	'78.00–78.24' : '92ccf6',
	'77.75–77.99' : 'a2d4f7',
	'77.50–77.74' : 'b3dbf8',
	'77.25–77.49' : 'c2e3fa',
	'77.00–77.24' : 'd4ebfb',
	'76.75–76.99' : 'e4f2fc',
	'76.50–76.74' : 'edf7fd',
	'76.25–76.49' : 'f4fafe',
	'76.00–76.24' : 'f8fbfe'
}

if CREATE_LEGEND_CODE:
    fn_create_legend_code(dd_legend_male)
# Out:
# {{Legend|#020f19|83.00–83.24}}
# {{Legend|#042136|82.75–82.99}}
# {{Legend|#062f4c|82.50–82.74}}
# {{Legend|#073a5e|82.25–82.49}}
# {{Legend|#08436e|82.00–82.24}}
# {{Legend|#0a4e7f|81.75–81.99}}
# {{Legend|#0b578d|81.50–81.74}}
# {{Legend|#0c609c|81.25–81.49}}
# {{Legend|#0d68a9|81.00–81.24}}
# {{Legend|#0e71b7|80.75–80.99}}
# {{Legend|#107ac6|80.50–80.74}}
# {{Legend|#1182d4|80.25–80.49}}
# {{Legend|#128be1|80.00–80.24}}
# {{Legend|#1c95ec|79.75–79.99}}
# {{Legend|#2e9eee|79.50–79.74}}
# {{Legend|#40a6ef|79.25–79.49}}
# {{Legend|#51aef0|79.00–79.24}}
# {{Legend|#61b5f2|78.75–78.99}}
# {{Legend|#6ebcf3|78.50–78.74}}
# {{Legend|#80c4f4|78.25–78.49}}
# {{Legend|#92ccf6|78.00–78.24}}
# {{Legend|#a2d4f7|77.75–77.99}}
# {{Legend|#b3dbf8|77.50–77.74}}
# {{Legend|#c2e3fa|77.25–77.49}}
# {{Legend|#d4ebfb|77.00–77.24}}
# {{Legend|#e4f2fc|76.75–76.99}}
# {{Legend|#edf7fd|76.50–76.74}}
# {{Legend|#f4fafe|76.25–76.49}}
# {{Legend|#f8fbfe|76.00–76.24}}

# %%
df_sel_year = filter_df(df_m, SELECTED_YEAR)
df_sel_year
# Out:
#            ——— 2020 ———
# Range: 79.43 – 82.88   (Aomori – Shiga)
# Number of groups: 11
# Number of values: 48
#             2020  group_label
# Shiga      82.88  82.75–82.99
# Nagano     82.54  82.50–82.74
# Nara       82.45  82.25–82.49
# Kyoto      82.34  82.25–82.49
# Gifu       82.24  82.00–82.24
# Hiroshima  82.17  82.00–82.24
# Toyama     82.08  82.00–82.24
# Okayama    82.08  82.00–82.24
# Kanagawa   82.06  82.00–82.24
# Ishikawa   81.97  81.75–81.99
# Kumamoto   81.96  81.75–81.99
# Miyagi     81.90  81.75–81.99
# Tokyo      81.86  81.75–81.99
# Fukui      81.85  81.75–81.99
# Oita       81.84  81.75–81.99
# Hyogo      81.78  81.75–81.99
# Yamanashi  81.76  81.75–81.99
# Tottori    81.76  81.75–81.99
# Aichi      81.75  81.75–81.99
# Shimane    81.71  81.50–81.74
# Mie        81.70  81.50–81.74
# Shizuoka   81.59  81.50–81.74
# Japan      81.58  81.50–81.74
# Niigata    81.55  81.50–81.74
# Fukuoka    81.55  81.50–81.74
# Yamagata   81.53  81.50–81.74
# Chiba      81.53  81.50–81.74
# Saitama    81.49  81.25–81.49
# Ehime      81.48  81.25–81.49
# Kagawa     81.48  81.25–81.49
# Saga       81.42  81.25–81.49
# Gunma      81.36  81.25–81.49
# Tokushima  81.32  81.25–81.49
# Wakayama   81.23  81.00–81.24
# Tochigi    81.22  81.00–81.24
# Yamaguchi  81.19  81.00–81.24
# Kochi      81.16  81.00–81.24
# Miyazaki   81.09  81.00–81.24
# Hokkaido   81.09  81.00–81.24
# Kagoshima  80.97  80.75–80.99
# Nagasaki   80.93  80.75–80.99
# Okinawa    80.92  80.75–80.99
# Osaka      80.89  80.75–80.99
# Iwate      80.89  80.75–80.99
# Ibaraki    80.89  80.75–80.99
# Fukushima  80.87  80.75–80.99
# Akita      80.46  80.25–80.49
# Aomori     79.43  79.25–79.49

# %%
ls_grouping = []
df_grouped = df_sel_year.groupby(['group_label']).apply(extract_indexes, dd_legend = dd_legend_male).loc[::-1]

# %%
jo = create_map_code(ls_grouping, title=f'{SELECTED_YEAR}: ♂', legend_color='#333333')  # legend_color='#0000bf'

pretty_jo = json.dumps(jo, indent=2, ensure_ascii=False)

with open(f"output/map_JSON -{SELECTED_YEAR}, male.txt", 'w', encoding="utf-8") as fh:
    fh.write(pretty_jo)

# %% [markdown]
# <br />
# <br />
#
# <h4>Statistics for females</h4>

# %%
dd_legend_female = {
    '89.00–89.24' : '1e0204',
    '88.75–88.99' : '41050a',
    '88.50–88.74' : '60070f',
    '88.25–88.49' : '840a14',
    '88.00–88.24' : 'a30d19',
    '87.75–87.99' : 'bd0f25',
    '87.50–87.74' : 'd81132',
    '87.25–87.49' : 'ec183b',
    '87.00–87.24' : 'ef3b59',
    '86.75–86.99' : 'f1536e',
    '86.50–86.74' : 'f2657d',
    '86.25–86.49' : 'f3768b',
    '86.00–86.24' : 'f58698',
    '85.75–85.99' : 'f696a6',
    '85.50–85.74' : 'f7a5b2',
    '85.25–85.49' : 'f8b3be',
    '85.00–85.24' : 'f9bfc6',
    '84.75–84.99' : 'facdd3',
    '84.50–84.74' : 'fbd8db',
    '84.25–84.49' : 'fce2e4',
    '84.00–84.24' : 'fdebed',
    '83.75–83.99' : 'fef3f4',
    '83.50–83.74' : 'fef8f9',
    '83.25–83.49' : 'fefafa',
}

if CREATE_LEGEND_CODE:
    fn_create_legend_code(dd_legend_female)
# Out:
# {{Legend|#1e0204|89.00–89.24}}
# {{Legend|#41050a|88.75–88.99}}
# {{Legend|#60070f|88.50–88.74}}
# {{Legend|#840a14|88.25–88.49}}
# {{Legend|#a30d19|88.00–88.24}}
# {{Legend|#bd0f25|87.75–87.99}}
# {{Legend|#d81132|87.50–87.74}}
# {{Legend|#ec183b|87.25–87.49}}
# {{Legend|#ef3b59|87.00–87.24}}
# {{Legend|#f1536e|86.75–86.99}}
# {{Legend|#f2657d|86.50–86.74}}
# {{Legend|#f3768b|86.25–86.49}}
# {{Legend|#f58698|86.00–86.24}}
# {{Legend|#f696a6|85.75–85.99}}
# {{Legend|#f7a5b2|85.50–85.74}}
# {{Legend|#f8b3be|85.25–85.49}}
# {{Legend|#f9bfc6|85.00–85.24}}
# {{Legend|#facdd3|84.75–84.99}}
# {{Legend|#fbd8db|84.50–84.74}}
# {{Legend|#fce2e4|84.25–84.49}}
# {{Legend|#fdebed|84.00–84.24}}
# {{Legend|#fef3f4|83.75–83.99}}
# {{Legend|#fef8f9|83.50–83.74}}
# {{Legend|#fefafa|83.25–83.49}}

# %%
df_sel_year = filter_df(df_f, SELECTED_YEAR)
df_sel_year
# Out:
#            ——— 2020 ———
# Range: 86.58 – 88.68   (Aomori – Tottori)
# Number of groups: 8
# Number of values: 48
#             2020  group_label
# Tottori    88.68  88.50–88.74
# Okayama    88.53  88.50–88.74
# Kumamoto   88.51  88.50–88.74
# Kyoto      88.49  88.25–88.49
# Shiga      88.39  88.25–88.49
# Nagano     88.39  88.25–88.49
# Hiroshima  88.39  88.25–88.49
# Oita       88.37  88.25–88.49
# Ishikawa   88.34  88.25–88.49
# Yamanashi  88.24  88.00–88.24
# Nara       88.18  88.00–88.24
# Okinawa    88.17  88.00–88.24
# Toyama     88.15  88.00–88.24
# Shimane    88.12  88.00–88.24
# Saga       88.11  88.00–88.24
# Hyogo      88.05  88.00–88.24
# Kanagawa   87.99  87.75–87.99
# Tokyo      87.96  87.75–87.99
# Fukuoka    87.91  87.75–87.99
# Fukui      87.88  87.75–87.99
# Yamaguchi  87.85  87.75–87.99
# Kochi      87.84  87.75–87.99
# Niigata    87.81  87.75–87.99
# Japan      87.73  87.50–87.74
# Miyagi     87.70  87.50–87.74
# Gifu       87.68  87.50–87.74
# Chiba      87.62  87.50–87.74
# Kagawa     87.62  87.50–87.74
# Aichi      87.61  87.50–87.74
# Kagoshima  87.60  87.50–87.74
# Mie        87.54  87.50–87.74
# Wakayama   87.52  87.50–87.74
# Miyazaki   87.48  87.25–87.49
# Shizuoka   87.47  87.25–87.49
# Osaka      87.47  87.25–87.49
# Nagasaki   87.46  87.25–87.49
# Akita      87.41  87.25–87.49
# Ehime      87.38  87.25–87.49
# Tokushima  87.33  87.25–87.49
# Saitama    87.32  87.25–87.49
# Hokkaido   87.28  87.25–87.49
# Gunma      87.27  87.25–87.49
# Iwate      87.18  87.00–87.24
# Yamagata   87.18  87.00–87.24
# Tochigi    87.08  87.00–87.24
# Ibaraki    87.07  87.00–87.24
# Fukushima  87.05  87.00–87.24
# Aomori     86.58  86.50–86.74

# %%
ls_grouping = []
df_grouped = df_sel_year.groupby(['group_label']).apply(extract_indexes, dd_legend = dd_legend_female).loc[::-1]

# %%
jo = create_map_code(ls_grouping, title=f'{SELECTED_YEAR}: ♀', legend_color='#333333')  # legend_color='#c20000'

pretty_jo = json.dumps(jo, indent=2, ensure_ascii=False)

with open(f"output/map_JSON -{SELECTED_YEAR}, female.txt", 'w', encoding="utf-8") as fh:
    fh.write(pretty_jo)

# %%
assert False

# %% [markdown]
# <br />
# <br />
#
# exploration:

# %%
print(round(85.71 - 82.22, 2))
print(int(round(85.75 - 82.00, 2) * 4))
print(int(round(85.8 - 82.2, 2) * 5))

# %%
print(round(82.88 - 78.78, 2))
print(int(round(83.00 - 78.75, 2) * 4))
print(int(round(83.0 - 78.6, 2) * 5))

# %%
print(round(88.68 - 85.55, 2))
print(int(round(88.75 - 85.50, 2) * 4))
print(int(round(88.8 - 85.4, 2) * 5))

# %% [markdown]
# <br />
# <br />
#
# creation of technical dictionaries:

# %%
ls = [
    '007800',
    '008800',
    '009800',
    '00a700',
    '00b800',
    '00cb00',
    '00e000',
    '00f000',
    '00ff00',
    '88ff00',
    'b8ff00',
    'deff00',
    'ffff00',
    'ffef00',
    'ffe000',
    'ffce00',
    'ffbc00',
    'ffac00',
    'ff9c00',
    'ff8700',
    'ff7400',
    'ff5200',
    'ff0000',
    'e10000',
    'c70000',
    'af0000',
    '9e0000',
    '8b0000',
    '790000',
    '670000',
    '580000'
]

def print_legend(ls, age):
    for col in ls:
        print(f"    '{age :.2f}–{age+0.24 :.2f}' : '{col}',")
        age -= 0.25

print_legend(ls, age=87.00)

# %%
ls = [
    '020f19',
    '042136',
    '062f4c',
    '073a5e',
    '08436e',
    '0a4e7f',
    '0b578d',
    '0c609c',
    '0d68a9',
    '0e71b7',
    '107ac6',
    '1182d4',
    '128be1',
    '1c95ec',
    '2e9eee',
    '40a6ef',
    '51aef0',
    '61b5f2',
    '6ebcf3',
    '80c4f4',
    '92ccf6',
    'a2d4f7',
    'b3dbf8',
    'c2e3fa',
    'd4ebfb',
    'e4f2fc',
    'edf7fd',
    'f4fafe',
    'f8fbfe'
]

print_legend(ls, age=84.00)

# %%
# v1
ls = [
    '1e0204',
    '3f050a',
    '5a070e',
    '700911',
    '860a15',
    '9c0c18',
    'ad0e1b',
    'bd0f25',
    'cd1030',
    'df1234',
    'ec2042',
    'ef3b59',
    'f04f6a',
    'f15d76',
    'f26a80',
    'f3768b',
    'f48295',
    'f58fa0',
    'f69aaa',
    'f7a4b2',
    'f8acb9',
    'f9b5c0',
    'f9bec5',
    'fac7cd',
    'fbcfd3',
    'fbd7da',
    'fcdfe2',
    'fde7e9',
    'fdeeef',
    'fef4f4',
    'fef8f9'
]

print_legend(ls, age=90.00)  # age=90.00

# %%
# v2
ls = [
    '1e0204',
    '41050a',
    '60070f',
    '840a14',
    'a30d19',
    'bd0f25',
    'd81132',
    'ec183b',
    'ef3b59',
    'f1536e',
    'f2657d',
    'f3768b',
    'f58698',
    'f696a6',
    'f7a5b2',
    'f8b3be',
    'f9bfc6',
    'facdd3',
    'fbd8db',
    'fce2e4',
    'fdebed',
    'fef3f4',
    'fef8f9',
    'fefafa'
]

print_legend(ls, age=89.00)
