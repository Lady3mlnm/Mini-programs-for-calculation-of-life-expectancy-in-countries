# %% [markdown]
# source of data: [Espérance de vie en 2025: Comparaisons régionales et départementales](https://www.insee.fr/fr/statistiques/2012749)<br>
# [List of French departments by life expectancy](https://en.wikipedia.org/wiki/List_of_French_departments_by_life_expectancy) /
# [Продолжительность жизни в департаментах Франции](https://ru.wikipedia.org/wiki/Продолжительность_жизни_в_департаментах_Франции) / [Espérance de vie humaine en France](https://fr.wikipedia.org/wiki/Espérance_de_vie_humaine_en_France)<br />
# [MapChart](https://www.mapchart.net/france.html)

# %%
import pandas as pd
from collections import namedtuple
import json

import sys
sys.path.append("..")
import mal_moduls_private.mal_total as mal

# %%
pd.options.display.min_rows = 6
pd.options.display.max_rows = 50

# %%
CREATE_LEGEND = True
YEAR = 2025

# %%
CountryGroup = namedtuple('CountryGroup', ['group_label', 'color', 'countries'])

# %%
df = pd.read_excel(f'data/France-{YEAR}.xlsx', sheet_name='REG', skiprows=4, skipfooter=2,
                   usecols="B:D", index_col='Unnamed: 1', na_values='nd')
df.rename(columns={'Hom.':'male', 'Fem.':'female'}, inplace=True)
df.head()
# Out:
#                          male  female
# Auvergne-Rhône-Alpes     81.1    86.2
# Bourgogne-Franche-Comté  79.0    85.3
# Bretagne                 79.6    85.3
# Centre-Val de Loire      79.9    85.1
# Corse                    81.6    86.3

# %%
df['ar_mean'] = ((df['female'] + df['male']) / 2).round(2)  # ! without rounding it is possible error during sorting
df = df[['male', 'ar_mean', 'female']]

df.head()
# Out:
#                          male  ar_mean  female
# Auvergne-Rhône-Alpes     81.1    83.65    86.2
# Bourgogne-Franche-Comté  79.0    82.15    85.3
# Bretagne                 79.6    82.45    85.3
# Centre-Val de Loire      79.9    82.50    85.1
# Corse                    81.6    83.95    86.3

# %%
# pip install xlrd

# %% [markdown]
# <br />
# <br />

# %%
df_metr = df.iloc[:13, :] \
            .sort_values(by=['ar_mean', 'male'], ascending=False)

df = pd.concat([df.loc[["France métropolitaine"], :], df_metr])

df
# Out:
#                             male  ar_mean  female
# France métropolitaine       80.4    83.15    85.9
# Île-de-France               82.0    84.25    86.5
# Corse                       81.6    83.95    86.3
# Auvergne-Rhône-Alpes        81.1    83.65    86.2
# Provence-Alpes-Côte d'Azur  80.8    83.45    86.1
# Pays de la Loire            80.4    83.25    86.1
# Occitanie                   80.6    83.20    85.8
# Nouvelle-Aquitaine          80.3    83.05    85.8
# Centre-Val de Loire         79.9    82.50    85.1
# Bretagne                    79.6    82.45    85.3
# Bourgogne-Franche-Comté     79.0    82.15    85.3
# Grand Est                   79.4    82.00    84.6
# Normandie                   78.9    81.95    85.0
# Hauts-de-France             78.4    81.25    84.1

# %% [markdown]
# <br />
# <br />

# %%
# just for interest, explore results: determine regions with max and min values, and also look at specific regions
# mal.min_and_max_values(df, row_center=["Provence-Alpes-Côte d'Azur", "France métropolitaine"], nmb=3, max_lng=9)

# %%
# # Some inner statistics for interest   # old version of the function
# def min_and_max(df, region_center=''):
#     print(f"Number of values: {len(df)}")
    
#     def find_3_largest(df):
#         t_df = df.nlargest(5)
#         t_df = t_df.reset_index()
#         return t_df.apply(lambda v: f"{v.iloc[1]:.1f} – {v.iloc[0]}", axis=1)

#     def find_3_smallest(df):
#         t_df = df.nsmallest(3).iloc[::-1]
#         t_df = t_df.reset_index()
#         return t_df.apply(lambda v: f"{v.iloc[1]:.1f} – {v.iloc[0]}", axis=1)
    
#     if region_center:
#         ser_center = df.loc[region_center].map(lambda v: f" —— {v} ——")
#         final_df = pd.concat([df.apply(find_3_largest), ser_center.to_frame().T, df.apply(find_3_smallest)])
#         final_df.index = ['max', 'max_2', 'max_3', 'max_4', 'max_5', 'metr. France', 'min_3', 'min_2', 'min']
#     else:
#         final_df = pd.concat([df.apply(find_3_largest), df.apply(find_3_smallest)])
#         final_df.index = ['max', 'max_2', 'max_3', 'max_4', 'max_5', 'min_3', 'min_2', 'min']
#     return final_df.style.set_properties(**{'text-align': 'left'})

# min_and_max(df, region_center='France métropolitaine')

# %%
# Alternative way to see the statistics
mal.min_and_max_values(df, row_center=["France métropolitaine"],
                       nmb=(5, 3), max_lng=16, show_difference=True)
# Out:
# Number of records: 14
# <style type="text/css">
# #T_41da1_row0_col0, #T_41da1_row0_col1, #T_41da1_row0_col2, #T_41da1_row1_col0, #T_41da1_row1_col1, #T_41da1_row1_col2, #T_41da1_row2_col0, #T_41da1_row2_col1, #T_41da1_row2_col2, #T_41da1_row3_col0, #T_41da1_row3_col1, #T_41da1_row3_col2, #T_41da1_row4_col0, #T_41da1_row4_col1, #T_41da1_row4_col2, #T_41da1_row5_col0, #T_41da1_row5_col1, #T_41da1_row5_col2, #T_41da1_row6_col0, #T_41da1_row6_col1, #T_41da1_row6_col2, #T_41da1_row7_col0, #T_41da1_row7_col1, #T_41da1_row7_col2, #T_41da1_row8_col0, #T_41da1_row8_col1, #T_41da1_row8_col2, #T_41da1_row9_col0, #T_41da1_row9_col1, #T_41da1_row9_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_41da1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41da1_level0_col0" class="col_heading level0 col0" >male</th>
#       <th id="T_41da1_level0_col1" class="col_heading level0 col1" >ar_mean</th>
#       <th id="T_41da1_level0_col2" class="col_heading level0 col2" >female</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41da1_level0_row0" class="row_heading level0 row0" >max</th>
#       <td id="T_41da1_row0_col0" class="data row0 col0" >82.0 -Île-de-France</td>
#       <td id="T_41da1_row0_col1" class="data row0 col1" >84.25 -Île-de-France</td>
#       <td id="T_41da1_row0_col2" class="data row0 col2" >86.5 -Île-de-France</td>
#     </tr>
#     <tr>
#       <th id="T_41da1_level0_row1" class="row_heading level0 row1" >max_2</th>
#       <td id="T_41da1_row1_col0" class="data row1 col0" >81.6 -Corse</td>
#       <td id="T_41da1_row1_col1" class="data row1 col1" >83.95 -Corse</td>
#       <td id="T_41da1_row1_col2" class="data row1 col2" >86.3 -Corse</td>
#     </tr>
#     <tr>
#       <th id="T_41da1_level0_row2" class="row_heading level0 row2" >max_3</th>
#       <td id="T_41da1_row2_col0" class="data row2 col0" >81.1 -Auvergne-Rhône-…</td>
#       <td id="T_41da1_row2_col1" class="data row2 col1" >83.65 -Auvergne-Rhône-…</td>
#       <td id="T_41da1_row2_col2" class="data row2 col2" >86.2 -Auvergne-Rhône-…</td>
#     </tr>
#     <tr>
#       <th id="T_41da1_level0_row3" class="row_heading level0 row3" >max_4</th>
#       <td id="T_41da1_row3_col0" class="data row3 col0" >80.8 -Provence-Alpes-…</td>
#       <td id="T_41da1_row3_col1" class="data row3 col1" >83.45 -Provence-Alpes-…</td>
#       <td id="T_41da1_row3_col2" class="data row3 col2" >86.1 -Provence-Alpes-…</td>
#     </tr>
#     <tr>
#       <th id="T_41da1_level0_row4" class="row_heading level0 row4" >max_5</th>
#       <td id="T_41da1_row4_col0" class="data row4 col0" >80.6 -Occitanie</td>
#       <td id="T_41da1_row4_col1" class="data row4 col1" >83.25 -Pays de la Loire</td>
#       <td id="T_41da1_row4_col2" class="data row4 col2" >86.1 -Pays de la Loire</td>
#     </tr>
#     <tr>
#       <th id="T_41da1_level0_row5" class="row_heading level0 row5" >France métropolitaine</th>
#       <td id="T_41da1_row5_col0" class="data row5 col0" > – 80.4 –</td>
#       <td id="T_41da1_row5_col1" class="data row5 col1" > – 83.15 –</td>
#       <td id="T_41da1_row5_col2" class="data row5 col2" > – 85.9 –</td>
#     </tr>
#     <tr>
#       <th id="T_41da1_level0_row6" class="row_heading level0 row6" >Δ</th>
#       <td id="T_41da1_row6_col0" class="data row6 col0" >3.6</td>
#       <td id="T_41da1_row6_col1" class="data row6 col1" >3.0</td>
#       <td id="T_41da1_row6_col2" class="data row6 col2" >2.4</td>
#     </tr>
#     <tr>
#       <th id="T_41da1_level0_row7" class="row_heading level0 row7" >min_3</th>
#       <td id="T_41da1_row7_col0" class="data row7 col0" >79.0 -Bourgogne-Franc…</td>
#       <td id="T_41da1_row7_col1" class="data row7 col1" >82.0 -Grand Est</td>
#       <td id="T_41da1_row7_col2" class="data row7 col2" >85.0 -Normandie</td>
#     </tr>
#     <tr>
#       <th id="T_41da1_level0_row8" class="row_heading level0 row8" >min_2</th>
#       <td id="T_41da1_row8_col0" class="data row8 col0" >78.9 -Normandie</td>
#       <td id="T_41da1_row8_col1" class="data row8 col1" >81.95 -Normandie</td>
#       <td id="T_41da1_row8_col2" class="data row8 col2" >84.6 -Grand Est</td>
#     </tr>
#     <tr>
#       <th id="T_41da1_level0_row9" class="row_heading level0 row9" >min</th>
#       <td id="T_41da1_row9_col0" class="data row9 col0" >78.4 -Hauts-de-France</td>
#       <td id="T_41da1_row9_col1" class="data row9 col1" >81.25 -Hauts-de-France</td>
#       <td id="T_41da1_row9_col2" class="data row9 col2" >84.1 -Hauts-de-France</td>
#     </tr>
#   </tbody>
# </table>

# %%
# remove record about metropolitan France as a whole
df.drop(index=['France métropolitaine'], inplace=True)

# %% [markdown]
# <br />
# <br />

# %%
# print(*df_metr.index.to_list(), sep='", "')

# %%
# renaming of provinces according to requirement of the online-service 'MapChart'
df.rename(index={
    "Île-de-France" : "Ile_de_France",
    "Auvergne-Rhône-Alpes" : "Auvergne_Rhone_Alpes",
    "Pays de la Loire" : "Pays_de_la_Loire",
    "Provence-Alpes-Côte d'Azur" : "Provence_Alpes_Cote_d_Azure",
    "Nouvelle-Aquitaine" : "Nouvelle_Aquitaine",
    "Centre-Val de Loire" : "Centre_Val_de_Loire",
    "Bourgogne-Franche-Comté" : "Bourgogne_Franche_Comte",
    "Grand Est" : "Grand_Est",
    "Hauts-de-France" : "Hauts_de_France",
}, inplace=True)

df.head(3)
# Out:
#                       male  ar_mean  female
# Ile_de_France         82.0    84.25    86.5
# Corse                 81.6    83.95    86.3
# Auvergne_Rhone_Alpes  81.1    83.65    86.2

# %% [markdown]
# <br />
# <br />
# <br />
#
# <h2> male </h2>

# %%
dd_legend_male = {
    '83.0–83.4' : '020f19',
    '82.5–82.9' : '062f4c',
    '82.0–82.4' : '08436e',
    '81.5–81.9' : '0b578d',
    '81.0–81.4' : '0d68a9',
    '80.5–80.9' : '107ac6',
    '80.0–80.4' : '128be1',
    '79.5–79.9' : '2e9eee',
    '79.0–79.4' : '51aef0',
    '78.5–78.9' : '6ebcf3',
    '78.0–78.4' : '92ccf6',
    '77.5–77.9' : 'b3dbf8',
    '77.0–77.4' : 'd4ebfb',
    '76.5–76.9' : 'edf7fd',
    '76.0–76.4' : 'f8fbfe'
}


def create_legend_code(dd_legend):
    for k, v in dd_legend.items():
        print(f"{{{{Legend|#{v}|{k}}}}}")  

if CREATE_LEGEND:
    create_legend_code(dd_legend_male)
# Out:
# {{Legend|#020f19|83.0–83.4}}
# {{Legend|#062f4c|82.5–82.9}}
# {{Legend|#08436e|82.0–82.4}}
# {{Legend|#0b578d|81.5–81.9}}
# {{Legend|#0d68a9|81.0–81.4}}
# {{Legend|#107ac6|80.5–80.9}}
# {{Legend|#128be1|80.0–80.4}}
# {{Legend|#2e9eee|79.5–79.9}}
# {{Legend|#51aef0|79.0–79.4}}
# {{Legend|#6ebcf3|78.5–78.9}}
# {{Legend|#92ccf6|78.0–78.4}}
# {{Legend|#b3dbf8|77.5–77.9}}
# {{Legend|#d4ebfb|77.0–77.4}}
# {{Legend|#edf7fd|76.5–76.9}}
# {{Legend|#f8fbfe|76.0–76.4}}

# %% [markdown]
# <br />
# <br />

# %%
def filter_df(df, selected_col='male'):
    filtered_df = df.loc[:, [selected_col]]   \
                    .dropna()

    filtered_df['group_label'] = filtered_df[selected_col].map(lambda x: f"{x * 4 // 2 / 2:.1f}–{x * 4 // 2 / 2 + 0.4:.1f}")
    
    min_value = filtered_df[selected_col].min()
    max_value = filtered_df[selected_col].max()
    
    print(f"           ——— {selected_col} ———")
    print(f"Range: {min_value:.1f} – {max_value:.1f}   " +
          f"({filtered_df[selected_col].idxmin()} – {filtered_df[selected_col].idxmax()})")
    print(f"Number of groups: {filtered_df['group_label'].nunique()}")
    print(f"Number of values: {len(filtered_df)}")

    return filtered_df

df_male = filter_df(df, selected_col='male')
df_male
# Out:
#            ——— male ———
# Range: 78.4 – 82.0   (Hauts_de_France – Ile_de_France)
# Number of groups: 9
# Number of values: 13
#                              male group_label
# Ile_de_France                82.0   82.0–82.4
# Corse                        81.6   81.5–81.9
# Auvergne_Rhone_Alpes         81.1   81.0–81.4
# Provence_Alpes_Cote_d_Azure  80.8   80.5–80.9
# Pays_de_la_Loire             80.4   80.0–80.4
# Occitanie                    80.6   80.5–80.9
# Nouvelle_Aquitaine           80.3   80.0–80.4
# Centre_Val_de_Loire          79.9   79.5–79.9
# Bretagne                     79.6   79.5–79.9
# Bourgogne_Franche_Comte      79.0   79.0–79.4
# Grand_Est                    79.4   79.0–79.4
# Normandie                    78.9   78.5–78.9
# Hauts_de_France              78.4   78.0–78.4

# %%
def extract_indexes(subdf, dd_legend=dd_legend_male):
    group_label = subdf['group_label'].iloc[0]
    countries = subdf.index.to_list()
    color = (dd_legend[group_label])
    
    ls_grouping.append(CountryGroup(group_label=group_label, countries=countries, color=color))

    return pd.Series([color, countries], index=['color', 'regions'])


ls_grouping = []
df_grouped = df_male.groupby(['group_label'])[['group_label']].apply(extract_indexes, dd_legend=dd_legend_male).loc[::-1]

df_grouped
# Out:
#               color                                   regions
# group_label
# 82.0–82.4    08436e                           [Ile_de_France]
# 81.5–81.9    0b578d                                   [Corse]
# 81.0–81.4    0d68a9                    [Auvergne_Rhone_Alpes]
# 80.5–80.9    107ac6  [Provence_Alpes_Cote_d_Azure, Occitanie]
# 80.0–80.4    128be1    [Pays_de_la_Loire, Nouvelle_Aquitaine]
# 79.5–79.9    2e9eee           [Centre_Val_de_Loire, Bretagne]
# 79.0–79.4    51aef0      [Bourgogne_Franche_Comte, Grand_Est]
# 78.5–78.9    6ebcf3                               [Normandie]
# 78.0–78.4    92ccf6                         [Hauts_de_France]

# %%
def create_map_code(ls_grouping, title='', legend_color='#000'):  # (ls_grouping, title='', legend_color='#000'):
    false, true = False, True

    jo = {
        "groups": { },
        "title": title,
        "hidden": [],
        "background": "#ffffff",
        "borders": "#000",
        "legendFont": "Century Gothic",
        "legendFontColor": legend_color,
        "legendBorderColor": "#00000000",
        "legendBgColor": "#00000000",
        "legendWidth": 100,
        "legendBoxShape": "square",
        "areBordersShown": true,
        "defaultColor": "#d1dbdd",
        "labelsColor": "#6a0707",
        "labelsFont": "Arial",
        "strokeWidth": "medium",
        "areLabelsShown": true,
        "uncoloredScriptColor": "#ffff33",
        "v6": true,
        "legendPosition": "custom",
        "legendX": 120,
        "legendY": 460,
        "legendSize": "large",
        "legendTranslateX": "0.00",
        "legendStatus": "show",
        "scalingPatterns": true,
        "legendRowsSameColor": true,
        "legendColumnCount": 1
    }

    for group_label, color, regions in ls_grouping[::-1]:
        jo["groups"][f"#{color}"] = {"label": group_label,
                                     "paths": [department.replace(' ', '_') for department in regions]}       

    return jo


jo = create_map_code(ls_grouping, title=f'{YEAR}: ♂', legend_color='#333333')  # legend_color='#0000bf'

pretty_jo = json.dumps(jo, indent=2, ensure_ascii=False)

with open(f"output/map_JSON -{YEAR}, regions, male.txt", 'w', encoding="utf-8") as fh:
    fh.write(pretty_jo)

# print(pretty_jo)

# %% [markdown]
# <br />
# <br />
# <br />
#
# <h2> female </h2>

# %%
dd_legend_female = {
    '88.0–88.4' : '1e0204',
    '87.5–87.9' : '60070f',
    '87.0–87.4' : 'a30d19',
    '86.5–86.9' : 'd81132',
    '86.0–86.4' : 'ef3b59',
    '85.5–85.9' : 'f2657d',
    '85.0–85.4' : 'f58698',
    '84.5–84.9' : 'f7a5b2',
    '84.0–84.4' : 'f9bfc6',
    '83.5–83.9' : 'fbd8db',
    '83.0–83.4' : 'fdebed',
    '82.5–82.9' : 'fef8f9'
}
 

if CREATE_LEGEND:
    create_legend_code(dd_legend_female)
# Out:
# {{Legend|#1e0204|88.0–88.4}}
# {{Legend|#60070f|87.5–87.9}}
# {{Legend|#a30d19|87.0–87.4}}
# {{Legend|#d81132|86.5–86.9}}
# {{Legend|#ef3b59|86.0–86.4}}
# {{Legend|#f2657d|85.5–85.9}}
# {{Legend|#f58698|85.0–85.4}}
# {{Legend|#f7a5b2|84.5–84.9}}
# {{Legend|#f9bfc6|84.0–84.4}}
# {{Legend|#fbd8db|83.5–83.9}}
# {{Legend|#fdebed|83.0–83.4}}
# {{Legend|#fef8f9|82.5–82.9}}

# %%
df_female = filter_df(df, selected_col='female')
df_female
# Out:
#            ——— female ———
# Range: 84.1 – 86.5   (Hauts_de_France – Ile_de_France)
# Number of groups: 6
# Number of values: 13
#                              female group_label
# Ile_de_France                  86.5   86.5–86.9
# Corse                          86.3   86.0–86.4
# Auvergne_Rhone_Alpes           86.2   86.0–86.4
# Provence_Alpes_Cote_d_Azure    86.1   86.0–86.4
# Pays_de_la_Loire               86.1   86.0–86.4
# Occitanie                      85.8   85.5–85.9
# Nouvelle_Aquitaine             85.8   85.5–85.9
# Centre_Val_de_Loire            85.1   85.0–85.4
# Bretagne                       85.3   85.0–85.4
# Bourgogne_Franche_Comte        85.3   85.0–85.4
# Grand_Est                      84.6   84.5–84.9
# Normandie                      85.0   85.0–85.4
# Hauts_de_France                84.1   84.0–84.4

# %%
ls_grouping = []
df_grouped = df_female.groupby(['group_label'])[['group_label']].apply(extract_indexes, dd_legend=dd_legend_female).loc[::-1]

df_grouped
# Out:
#               color                                            regions
# group_label
# 86.5–86.9    d81132                                    [Ile_de_France]
# 86.0–86.4    ef3b59  [Corse, Auvergne_Rhone_Alpes, Provence_Alpes_C...
# 85.5–85.9    f2657d                    [Occitanie, Nouvelle_Aquitaine]
# 85.0–85.4    f58698  [Centre_Val_de_Loire, Bretagne, Bourgogne_Fran...
# 84.5–84.9    f7a5b2                                        [Grand_Est]
# 84.0–84.4    f9bfc6                                  [Hauts_de_France]

# %%
jo = create_map_code(ls_grouping, title=f'{YEAR}: ♀', legend_color='#333333')  # legend_color='#c20000'

pretty_jo = json.dumps(jo, indent=2, ensure_ascii=False)

with open(f"output/map_JSON -{YEAR}, regions, female.txt", 'w', encoding="utf-8") as fh:
    fh.write(pretty_jo)

# print(pretty_jo)

# %% [markdown]
# ♂ <br />
# ♀
